# %% [markdown]
# <a href="https://colab.research.google.com/github/tsnow2010/DATA601/blob/main/DATA601_Project1/data/Testing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# Read in movie_data.csv from Github
movie_data_url = 'https://raw.githubusercontent.com/tsnow2010/DATA601/refs/heads/main/DATA601_Project1/data/movie_data.csv'
df = pd.read_csv(movie_data_url)

# Display first 5 rows of data
df.sample(5)
# Out:
#                        Title    Year              Genre(s)  IMDB  \
# 1972               Stop-Loss  2008.0            Drama, War   6.4
# 3236              The Player  1992.0  Comedy, Crime, Drama   7.5
# 3833          Love and Death  1975.0           Comedy, War   7.6
# 5217               Firstborn  1984.0       Drama, Thriller   6.2
# 1747  Fun with Dick and Jane  2005.0         Comedy, Crime   6.2
#
#      Rotten Tomatoes  Metacritic   TMDB # of IMDB Votes  \
# 1972              64        61.0  6.131          20,976
# 3236              97        86.0  7.200          66,904
# 3833             100        89.0  7.500          41,525
# 5217           56/10        56.0  5.800           2,748
# 1747              29        47.0  6.198         155,715
#
#                                             # of Awards  \
# 1972                             2 wins & 5 nominations
# 3236  Nominated for 3 Oscars. 24 wins & 33 nominatio...
# 3833                               1 win & 1 nomination
# ...

# %%
# Test API functionality here:

from Movie import Movie

# Pull movie data using Movie Class and (2) APIs
movie = Movie('Trenchcoat',1983)
movie.get_movie_data()
