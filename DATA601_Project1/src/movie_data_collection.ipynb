# %% [markdown]
# # Create 'movie_data.csv' using Movie.py

# %%
import pandas as pd
from Movie import Movie
import csv
import re

# %% [markdown]
# #### Step 1:
#
# Take list from IMDB of domestic films released from 1972 to 2016 and (7) lists of original movies from streaming services, pull titles and years, and put data in 'movie_year_from_1972_2023.csv'

# %%
# Gets titles and years and writes to 'movie_year_from_1972_2023.csv'

files1 = ['data/us_released_movies_1972_to_2016.csv',
         'data/Streaming Movie Lists/amazon_prime_movie_list.csv',
         'data/Streaming Movie Lists/apple_tv_movie_list.csv',
         'data/Streaming Movie Lists/disney_plus_movie_list.csv',
         'data/Streaming Movie Lists/hbo_movie_list.csv',
         'data/Streaming Movie Lists/hulu_programming_list.csv',
         'data/Streaming Movie Lists/netflix_movie_list.csv',
         'data/Streaming Movie Lists/paramount_plus_movie_list.csv'
        ]
         
Movie.get_titles_from_csv(files1,'movie_year_from_1972_2023.csv')

# %% [markdown]
# #### Step 2:
# Using HTML pages from Box Office Mojo, pull titles and years of domestic films made from 2017 to 2023 to supplement the lists from files1.

# %%
# Below code creates 'movie_year_from_1972_2023.csv' containing title,year of every domestic movie from 1972-2023.

# List of html files of domestic movies by year indicated in name
files2 = ['data/Domestic Movies from 2017-2023/Domestic Box Office For 2017 - Box Office Mojo.txt',
         'data/Domestic Movies from 2017-2023/Domestic Box Office For 2018 - Box Office Mojo.txt',
         'data/Domestic Movies from 2017-2023/Domestic Box Office For 2019 - Box Office Mojo.txt',
         'data/Domestic Movies from 2017-2023/Domestic Box Office For 2020 - Box Office Mojo.txt',
         'data/Domestic Movies from 2017-2023/Domestic Box Office For 2021 - Box Office Mojo.txt',
         'data/Domestic Movies from 2017-2023/Domestic Box Office For 2022 - Box Office Mojo.txt',
         'data/Domestic Movies from 2017-2023/Domestic Box Office For 2023 - Box Office Mojo.txt']

Movie.get_titles_from_html(files2, 'movie_year_from_1972_2023.csv')

# %% [markdown]
# #### Step 2.5:
# Using HTML pages from Wikipedia, pull titles and years of domestic films made from 1972 to 2023 to supplement the lists from files1, files2.

# %%
Movie.get_titles_from_webscraping('movie_year_from_1972_2023.csv')

# %% [markdown]
# #### Step 3:
# Because the dataset, movie_year_from_1972_2023.csv, contains a lot of duplicates, we now clean the data and remove those duplicates.

# %% [markdown]
# Check for duplicate rows in movie_year_from_1972_2023.csv.

# %%
import pandas as pd
import requests
import json

df = pd.read_csv('movie_year_from_1972_2023.csv')
df[df.duplicated() == True]
# Out:
#                      title    year
# 4677                 Chaos  2005.0
# 8797                  Emma  1996.0
# 9501              Brooklyn  2015.0
# 9542                Solace  2015.0
# 9832              Delirium  2014.0
# ...                    ...     ...
# 160574               Golda  2023.0
# 160576              Origin  2023.0
# 160578    The Perfect Find  2023.0
# 160581       The Holdovers  2023.0
# 160582  Knock at the Cabin  2023.0
#
# [144255 rows x 2 columns]

# %% [markdown]
# Remove duplicates from movie_year_from_1972_2023.csv and verify removal.

# %%
df_no_dups = df.drop_duplicates()
df_no_dups[df_no_dups.duplicated() == True]
# Out:
# Empty DataFrame
# Columns: [title, year]
# Index: []

# %%
print("Original Dataset had", df.shape[0],'rows.')
print("Cleaned Dataset has", df_no_dups.shape[0],'rows.')
# Out:
# Original Dataset had 160583 rows.
# Cleaned Dataset has 16328 rows.

# %% [markdown]
# - Export the pandas dataset to 'no_dups_movie_year_from_1972_2023.xlsx'.
# - Remove numerical index manually.

# %%
df_no_dups.to_excel('no_dups_movie_year_from_1972_2023.xlsx')

# %% [markdown]
# #### Step 4:
#
# With no_dups_movie_year_from_1972_2023.csv now containing all domestic movies made from 1972 to 2023, **make_movie_data()** does the following:
#
# * Creates movie_data.csv and writes first row containing column names.
# * Iterates through each row in movie_year_from_1972_2023, requests movie data from (2) APIs, and appends to movie_data.csv.
# * The only parameter is 'start' which is either:
#   * **1 (int)** to start from the beginning of the 'no_dups_movie_year_from_1972_2023.csv' dataset.
#   * **'Movie Title/YearReleased'** to start from the last movie found, as indicated from the bottom of movie_data.csv.
#     * For example, "The Terminator/1984" would be valid input.

# %%
def make_movie_data(start):

    if start == 1:
        # Writes first line of 'movie_data.csv'
        with open('movie_data.csv','w') as file:
            writer = csv.writer(file,delimiter=',')
            writer.writerow(['Title',
                            'Year',
                            'Genre(s)',
                            'IMDB',
                            'Rotten Tomatoes',
                            'Metacritic',
                            'TMDB',
                            '# of IMDB Votes',
                            '# of Awards',
                            'Gross Domestic Box Office Sales ($)',
                            'Media',
                            'Directors',
                            'Origin'])
        
    # Writes the dataset
    with open('no_dups_movie_year_from_1972_2023.csv','r',buffering=1) as file:
        reader = csv.reader(file,delimiter=',')
        
        if start != 1:
            row = next(reader)
            while (row[0] + '/' + row[1] != start):
                row = next(reader)
            for row in reader:
                new_movie = Movie(row[0],row[1])
                new_movie.get_movie_data()
        else:
            header = next(reader)
            for row in reader:
                new_movie = Movie(row[0],row[1])
                new_movie.get_movie_data()

# %% [markdown]
# Below commands invoke make_movie_data().

# %%
# Use below line to "pick up" after last movie pulled from OMDB API
make_movie_data("The Hollow Point/2016") #Resume here!
# Out:
# This was written to movie_data.csv: The Hollywood Complex 2011
# This was written to movie_data.csv: The Hollywood Knights 1980
# This was written to movie_data.csv: The Hollywood Revue of 1929 1929
# This was written to movie_data.csv: The Holy Girl 2004
# This was written to movie_data.csv: The Holy Innocents 1984
# This was written to movie_data.csv: The Holy Land 2001
# This was written to movie_data.csv: The Holy Land 2003
# This was written to movie_data.csv: The Holy Man 1965
# This was written to movie_data.csv: The Holy Modal Rounders: Bound to Lose 2007
# This was written to movie_data.csv: The Holy Mountain 1926
# This was written to movie_data.csv: The Holy Mountain 1973
# This was written to movie_data.csv: The Home Song Stories 2007
# This was written to movie_data.csv: The Home Teachers 2004
# This was written to movie_data.csv: The Home and the World 1985
# This was written to movie_data.csv: The Home of Dark Butterflies 2008
# This was written to movie_data.csv: The Homecoming 1973
# This was written to movie_data.csv: The Homesman 2014
# This was written to movie_data.csv: The Homestretch 2014
# This was written to movie_data.csv: The Honey Pot 1967
# This was written to movie_data.csv: The Honeymoon Killers 1970
# This was written to movie_data.csv: The Honeymoon Machine 1961
# This was written to movie_data.csv: The Honeymooners 2005
# This was written to movie_data.csv: The Honkers 1972
# This was written to movie_data.csv: The Honorary Consul 1983
# This was written to movie_data.csv: The Hoodlum 1919
# This was written to movie_data.csv: The Hoodlum 1951
# This was written to movie_data.csv: The Hoodlum Priest 1961
# This was written to movie_data.csv: The Hooligan Factory 2014
# This was written to movie_data.csv: The Hope Factory 2014
# This was written to movie_data.csv: The Horde 2009
# This was written to movie_data.csv: The Hornet's Nest 2014
# This was written to movie_data.csv: The Horrible Dr. Hichcock 1962
# This was written to movie_data.csv: The Horribly Slow Murderer with the Extremely Inefficient Weapon 2008
# This was written to movie_data.csv: The Horror Show 1989
# This was written to movie_data.csv: The Horror of Frankenstein 1970
# This was written to movie_data.csv: The Horror of Party Beach 1964
# This was written to movie_data.csv: The Horse Boy 2009
# This was written to movie_data.csv: The Horse Soldiers 1959
# This was written to movie_data.csv: The Horse Whisperer 1998
# This was written to movie_data.csv: The Horse in the Gray Flannel Suit 1968
# This was written to movie_data.csv: The Horse's Mouth 1958
# This was written to movie_data.csv: The Horseman 2008
# This was written to movie_data.csv: The Horseman on the Roof 1995
# This was written to movie_data.csv: The Horsemen 1971
# This was written to movie_data.csv: The Horseplayer 1990
# This was written to movie_data.csv: The Hospital 1971
# This was written to movie_data.csv: The Host 2006
# This was written to movie_data.csv: The Host 2013
# This was written to movie_data.csv: The Hot Chick 2002
# This was written to movie_data.csv: The Hot Flashes 2013
# This was written to movie_data.csv: The Hot Rock 1972
# This was written to movie_data.csv: The Hot Spot 1990
# This was written to movie_data.csv: The Hotel New Hampshire 1984
# This was written to movie_data.csv: The Hottest State 2006
# This was written to movie_data.csv: The Hottest State 2007
# This was written to movie_data.csv: The Hottie & The Nottie 2008
# This was written to movie_data.csv: The Hottie & the Nottie 2008
# This was written to movie_data.csv: The Hotwives of Las Vegas 2015
# This was written to movie_data.csv: The Hotwives of Orlando 2014
# This was written to movie_data.csv: The Hound of the Baskervilles 1939
# This was written to movie_data.csv: The Hound of the Baskervilles 1959
# This was written to movie_data.csv: The Hound of the Baskervilles 1978
# This was written to movie_data.csv: The Hound of the Baskervilles 1983
# This was written to movie_data.csv: The Hound of the Baskervilles 1988
# This was written to movie_data.csv: The Hound of the Baskervilles 2000
# This was written to movie_data.csv: The Hound of the Baskervilles 2002
# This was written to movie_data.csv: The Hounds 2011
# This was written to movie_data.csv: The Hour Before the Dawn 1944
# This was written to movie_data.csv: The Hour of the Furnaces 1968
# This was written to movie_data.csv: The Hour of the Lynx 2013
# This was written to movie_data.csv: The Hourglass Sanatorium 1973
# This was written to movie_data.csv: The Hours 2002
# This was written to movie_data.csv: The House 2011
# This was written to movie_data.csv: The House 2016
# This was written to movie_data.csv: The House 2017
# This was written to movie_data.csv: The House Across the Lake 1954
# This was written to movie_data.csv: The House Bunny 2008
# This was written to movie_data.csv: The House I Live In 2012
# This was written to movie_data.csv: The House Is Black 1963
# This was written to movie_data.csv: The House Next Door: Meet the Blacks 2 2021
# This was written to movie_data.csv: The House That Dripped Blood 1971
# This was written to movie_data.csv: The House That Screamed 1969
# This was written to movie_data.csv: The House That Swift Built 1982
# This was written to movie_data.csv: The House Under the Rocks 1959
# This was written to movie_data.csv: The House Where Evil Dwells 1982
# This was written to movie_data.csv: The House Without a Christmas Tree 1972
# This was written to movie_data.csv: The House at the End of Time 2013
# This was written to movie_data.csv: The House by the Cemetery 1981
# This was written to movie_data.csv: The House in Montevideo 1951
# This was written to movie_data.csv: The House in Nightmare Park 1973
# This was written to movie_data.csv: The House of Branching Love 2009
# This was written to movie_data.csv: The House of Darkness 1913
# This was written to movie_data.csv: The House of Exorcism 1975
# This was written to movie_data.csv: The House of Fear 1945
# This was written to movie_data.csv: The House of Fools 1985
# This was written to movie_data.csv: The House of Ghosts 1908
# This was written to movie_data.csv: The House of Light 1969
# This was written to movie_data.csv: The House of Mirth 2000
# This was written to movie_data.csv: The House of Rothschild 1934
# This was written to movie_data.csv: The House of Sand 2005
# This was written to movie_data.csv: The House of Seven Corpses 1974
# This was written to movie_data.csv: The House of Small Cubes 2008
# This was written to movie_data.csv: The House of Smiles 1991
# This was written to movie_data.csv: The House of Suh 2010
# This was written to movie_data.csv: The House of The Spirits
# This was written to movie_data.csv: The House of Tomorrow 2018
# This was written to movie_data.csv: The House of Usher 2007
# This was written to movie_data.csv: The House of Yes 1997
# This was written to movie_data.csv: The House of the Devil 2009
# This was written to movie_data.csv: The House of the Seven Gables 1940
# This was written to movie_data.csv: The House of the Spirits 1993
# This was written to movie_data.csv: The House of the Spirits 1994
# This was written to movie_data.csv: The House of the Yellow Carpet 1983
# This was written to movie_data.csv: The House on 56th Street 1933
# This was written to movie_data.csv: The House on 92nd Street 1945
# This was written to movie_data.csv: The House on Carroll Street 1988
# This was written to movie_data.csv: The House on Pine Street 2015
# This was written to movie_data.csv: The House on Sorority Row 1983
# This was written to movie_data.csv: The House on Telegraph Hill 1951
# This was written to movie_data.csv: The House with Laughing Windows 1976
# This was written to movie_data.csv: The House with a Clock in Its Walls 2018
# This was written to movie_data.csv: The Householder 1963
# This was written to movie_data.csv: The Housekeeper 2002
# This was written to movie_data.csv: The Housemaid 1960
# This was written to movie_data.csv: The Housemaid 2010
# This was written to movie_data.csv: The Houses Are Full of Smoke 1987
# This was written to movie_data.csv: The Houses October Built 2014
# This was written to movie_data.csv: The Housewife & the Shah Shocker 2021
# This was written to movie_data.csv: The Housewife and the Hustler 2021
# This was written to movie_data.csv: The Houston Story 1956
# This was written to movie_data.csv: The Howards of Virginia 1940
# This was written to movie_data.csv: The Howling 1981
# This was written to movie_data.csv: The Howling Miller 1982
# This was written to movie_data.csv: The Howling: New Moon Rising 1995
# This was written to movie_data.csv: The Howling: Reborn 2011
# This was written to movie_data.csv: The Hucksters 1947
# This was written to movie_data.csv: The Hudsucker Proxy 1994
# This was written to movie_data.csv: The Human Behavior Experiments 2006
# This was written to movie_data.csv: The Human Centipede (First Sequence) 2009
# This was written to movie_data.csv: The Human Centipede 2 (Full Sequence) 2011
# This was written to movie_data.csv: The Human Centipede 3 (Final Sequence) 2015
# This was written to movie_data.csv: The Human Comedy 1943
# This was written to movie_data.csv: The Human Condition I: No Greater Love 1959
# This was written to movie_data.csv: The Human Condition II: Road to Eternity 1959
# This was written to movie_data.csv: The Human Condition III: A Soldier's Prayer 1961
# This was written to movie_data.csv: The Human Contract 2008
# This was written to movie_data.csv: The Human Duplicators 1965
# This was written to movie_data.csv: The Human Dutch 1963
# This was written to movie_data.csv: The Human Experience 2008
# This was written to movie_data.csv: The Human Experiment 2013
# This was written to movie_data.csv: The Human Factor 1979
# This was written to movie_data.csv: The Human Factor 2013
# This was written to movie_data.csv: The Human Family Tree 2009
# This was written to movie_data.csv: The Human Pyramid 1899
# This was written to movie_data.csv: The Human Race 2013
# This was written to movie_data.csv: The Human Resources Manager 2011
# This was written to movie_data.csv: The Human Scale 2013
# This was written to movie_data.csv: The Human Stain 2003
# This was written to movie_data.csv: The Human Surge 2016
# This was written to movie_data.csv: The Human Tornado 1976
# This was written to movie_data.csv: The Humanoid 1979
# This was written to movie_data.csv: The Humans 2021
# This was written to movie_data.csv: The Humbling 2014
# This was written to movie_data.csv: The Humbling 2015
# This was written to movie_data.csv: The Hunchback 1997
# This was written to movie_data.csv: The Hunchback of Notre Dame 1923
# This was written to movie_data.csv: The Hunchback of Notre Dame 1939
# This was written to movie_data.csv: The Hunchback of Notre Dame 1956
# This was written to movie_data.csv: The Hunchback of Notre Dame 1996
# This was written to movie_data.csv: The Hunchback of Notre Dame II 2002
# This was written to movie_data.csv: The Hunchback of Notre-Dame 1986
# This was written to movie_data.csv: The Hunchback of Paris 1959
# This was written to movie_data.csv: The Hunchedback Horse 1947
# This was written to movie_data.csv: The Hundred-Foot Journey 2014
# This was written to movie_data.csv: The Hunger 1983
# This was written to movie_data.csv: The Hunger Games 2012
# This was written to movie_data.csv: The Hunger Games: Catching Fire 2013
# This was written to movie_data.csv: The Hunger Games: Mockingjay - Part 1 2014
# This was written to movie_data.csv: The Hunger Games: Mockingjay - Part 2 2015
# This was written to movie_data.csv: The Hunger Games: Mockingjay – Part 1 2014
# This was written to movie_data.csv: The Hunger Games: Mockingjay – Part 2 2015
# This was written to movie_data.csv: The Hunger Games: The Ballad of Songbirds & Snakes 2023
# This was written to movie_data.csv: The Hungover Games 2014
# This was written to movie_data.csv: The Hunley 1999
# This was written to movie_data.csv: The Huns 1960
# This was written to movie_data.csv: The Hunt 1966
# This was written to movie_data.csv: The Hunt 2012
# This was written to movie_data.csv: The Hunt 2020
# This was written to movie_data.csv: The Hunt for Eagle One 2006
# This was written to movie_data.csv: The Hunt for Eagle One: Crash Point 2006
# This was written to movie_data.csv: The Hunt for Gollum 2009
# This was written to movie_data.csv: The Hunt for Red October 1990
# This was written to movie_data.csv: The Hunt for the BTK Killer 2005
# This was written to movie_data.csv: The Hunt for the Hidden Relic 2002
# This was written to movie_data.csv: The Hunt for the Unicorn Killer 1999
# This was written to movie_data.csv: The Hunted 1995
# This was written to movie_data.csv: The Hunted 2003
# This was written to movie_data.csv: The Hunter 1980
# This was written to movie_data.csv: The Hunter 2010
# This was written to movie_data.csv: The Hunter 2011
# This was written to movie_data.csv: The Hunter's Prayer 2017
# This was written to movie_data.csv: The Hunters 1957
# This was written to movie_data.csv: The Hunters 1958
# This was written to movie_data.csv: The Hunters 1977
# This was written to movie_data.csv: The Hunters 1996
# This was written to movie_data.csv: The Hunters 2011
# This was written to movie_data.csv: The Hunters 2013
# This was written to movie_data.csv: The Hunters of the Golden Cobra 1982
# This was written to movie_data.csv: The Hunting Ground 2015
# This was written to movie_data.csv: The Hunting Party 1971
# This was written to movie_data.csv: The Hunting Party 2007
# This was written to movie_data.csv: The Hunting of the President 2004
# This was written to movie_data.csv: The Huntresses 2014
# This was written to movie_data.csv: The Huntsman: Winter's War 2016
# This was written to movie_data.csv: The Hurdy-Gurdy 1955
# This was written to movie_data.csv: The Hurricane 1937
# This was written to movie_data.csv: The Hurricane 1999
# This was written to movie_data.csv: The Hurricane Express 1932
# This was written to movie_data.csv: The Hurricane Heist 2018
# This was written to movie_data.csv: The Hurt Locker 2008
# This was written to movie_data.csv: The Hurt Locker 2009
# This was written to movie_data.csv: The Husband She Met Online 2013
# This was written to movie_data.csv: The Hustle 2019
# This was written to movie_data.csv: The Hustler 1961
# This was written to movie_data.csv: The Hyperboloid of Engineer Garin 1965
# This was written to movie_data.csv: The Hyperions 2022
# This was written to movie_data.csv: The Hypnotic Eye 1960
# This was written to movie_data.csv: The Hypnotist 2012
# This was written to movie_data.csv: The Hypothesis of the Stolen Painting 1978
# This was written to movie_data.csv: The I Inside 2004
# This was written to movie_data.csv: The Ice Age Adventures of Buck Wild 2022
# This was written to movie_data.csv: The Ice Dragon 2012
# This was written to movie_data.csv: The Ice Follies of 1939 1939
# This was written to movie_data.csv: The Ice Harvest 2005
# This was written to movie_data.csv: The Ice House 1997
# This was written to movie_data.csv: The Ice Pirates 1984
# This was written to movie_data.csv: The Ice Princess 1996
# This was written to movie_data.csv: The Ice Road 2021
# This was written to movie_data.csv: The Ice Storm 1997
# This was written to movie_data.csv: The Iceman 2012
# This was written to movie_data.csv: The Iceman 2013
# This was written to movie_data.csv: The Iceman Cometh 1973
# This was written to movie_data.csv: The Iceman Tapes: Conversations with a Killer 1992
# This was written to movie_data.csv: The Iceman and the Psychiatrist 2004
# This was written to movie_data.csv: The Iceman: Confessions of a Mafia Hitman 2001
# This was written to movie_data.csv: The Icicle Thief 1989
# This was written to movie_data.csv: The Ideal 2016
# This was written to movie_data.csv: The Idealist 2015
# This was written to movie_data.csv: The Identical 2014
# This was written to movie_data.csv: The Identity Theft of Mitch Mustain 2013
# This was written to movie_data.csv: The Ides of March 2011
# This was written to movie_data.csv: The Idiot 1951
# This was written to movie_data.csv: The Idiot 2003
# This was written to movie_data.csv: The Idiot Returns 1999
# This was written to movie_data.csv: The Idiotmaker's Gravity Tour 2011
# This was written to movie_data.csv: The Idiots 1998
# This was written to movie_data.csv: The Idle Class 1921
# This was written to movie_data.csv: The Idolmaker 1980
# This was written to movie_data.csv: The Iguana with the Tongue of Fire 1971
# This was written to movie_data.csv: The Illusionist 2006
# This was written to movie_data.csv: The Illusionist 2010
# This was written to movie_data.csv: The Illustrated Man 1969
# This was written to movie_data.csv: The Illustrated Mum 2003
# This was written to movie_data.csv: The Image 1975
# This was written to movie_data.csv: The Image Revolution 2013
# This was written to movie_data.csv: The Imaginarium of Doctor Parnassus 2009
# This was written to movie_data.csv: The Imaginary Voyage 1926
# This was written to movie_data.csv: The Imitation Game 2014
# This was written to movie_data.csv: The Immaculate Conception of Little Dizzle 2010
# This was written to movie_data.csv: The Immature 2011
# This was written to movie_data.csv: The Immigrant 1917
# This was written to movie_data.csv: The Immigrant 2013
# This was written to movie_data.csv: The Immoral Mr. Teas 1959
# This was written to movie_data.csv: The Immortal Bachelor 1975
# This was written to movie_data.csv: The Immortal Life of Henrietta Lacks 2017
# This was written to movie_data.csv: The Immortal Story 1968
# This was written to movie_data.csv: The Immortal Voyage of Captain Drake 2009
# This was written to movie_data.csv: The Immortalists 2014
# This was written to movie_data.csv: The Immortals 1974
# This was written to movie_data.csv: The Immortals 1995
# This was written to movie_data.csv: The Imp 1981
# This was written to movie_data.csv: The Imperceptable Transmutations 1904
# This was written to movie_data.csv: The Importance of Being Earnest 1952
# This was written to movie_data.csv: The Importance of Being Earnest 1986
# This was written to movie_data.csv: The Importance of Being Earnest 2002
# This was written to movie_data.csv: The Importance of Tying Your Own Shoes 2011
# This was written to movie_data.csv: The Impossible 2012
# This was written to movie_data.csv: The Impossible Convicts 1906
# This was written to movie_data.csv: The Impossible Hour 1974
# This was written to movie_data.csv: The Impossible Voyage 1904
# This was written to movie_data.csv: The Impossible Years 1968
# This was written to movie_data.csv: The Imposter 2012
# This was written to movie_data.csv: The Impostors 1998
# This was written to movie_data.csv: The Improv: 50 Years Behind the Brick Wall 2013
# This was written to movie_data.csv: The In Between 2022
# This was written to movie_data.csv: The In Crowd 1988
# This was written to movie_data.csv: The In Crowd 2000
# This was written to movie_data.csv: The In-Laws 1979
# This was written to movie_data.csv: The In-Laws 2003
# This was written to movie_data.csv: The Inbetweeners 2011
# This was written to movie_data.csv: The Inbetweeners 2 2014
# This was written to movie_data.csv: The Inbetweeners Movie 2011
# This was written to movie_data.csv: The Incident 1967
# This was written to movie_data.csv: The Incident 1990
# This was written to movie_data.csv: The Incident 2014
# This was written to movie_data.csv: The Incite Mill 2010
# This was written to movie_data.csv: The Incredible 2-Headed Transplant 1971
# This was written to movie_data.csv: The Incredible Burt Wonderstone 2013
# This was written to movie_data.csv: The Incredible Hulk 2008
# This was written to movie_data.csv: The Incredible Hulk Returns 1988
# This was written to movie_data.csv: The Incredible Jessica James 2017
# This was written to movie_data.csv: The Incredible Journey 1963
# This was written to movie_data.csv: The Incredible Kung Fu Master 1979
# This was written to movie_data.csv: The Incredible Melting Man 1977
# This was written to movie_data.csv: The Incredible Mr. Limpet 1964
# This was written to movie_data.csv: The Incredible Petrified World 1957
# This was written to movie_data.csv: The Incredible Shrinking Man 1957
# This was written to movie_data.csv: The Incredible Shrinking Woman 1981
# This was written to movie_data.csv: The Incredibles 2004
# This was written to movie_data.csv: The Incredibly Strange Creatures Who Stopped Living and Became Mixed-Up Zombies!!? 1964
# This was written to movie_data.csv: The Incredibly True Adventure of Two Girls In Love 1995
# This was written to movie_data.csv: The Incredibly True Adventure of Two Girls in Love 1995
# This was written to movie_data.csv: The Incubus 1982
# This was written to movie_data.csv: The Indecent Woman 1991
# This was written to movie_data.csv: The Independent 2000
# This was written to movie_data.csv: The Independent 2022
# This was written to movie_data.csv: The Indian 2007
# This was written to movie_data.csv: The Indian Fighter 1955
# This was written to movie_data.csv: The Indian Runner 1991
# This was written to movie_data.csv: The Indian Tomb 1959
# This was written to movie_data.csv: The Indian in the Cupboard 1995
# This was written to movie_data.csv: The Inevitable Defeat of Mister & Pete 2013
# This was written to movie_data.csv: The Inextinguishable Fire 1969
# This was written to movie_data.csv: The Infernal Cakewalk 1903
# This was written to movie_data.csv: The Infernal Caldron 1903
# This was written to movie_data.csv: The Infidel 2009
# This was written to movie_data.csv: The Infidel 2010
# This was written to movie_data.csv: The Infiltrator 1995
# This was written to movie_data.csv: The Infiltrator 2016
# This was written to movie_data.csv: The Infinite Man 2014
# This was written to movie_data.csv: The Infinite Worlds of H.G. Wells 2001
# This was written to movie_data.csv: The Informant! 2009
# This was written to movie_data.csv: The Informer 1935
# This was written to movie_data.csv: The Informer 2020
# This was written to movie_data.csv: The Informers 2008
# This was written to movie_data.csv: The Informers 2009
# This was written to movie_data.csv: The Inglorious Bastards 1978
# This was written to movie_data.csv: The Inhabitants 2015
# This was written to movie_data.csv: The Inhabited Island 2008
# This was written to movie_data.csv: The Inhabited Island 2: Rebellion 2009
# This was written to movie_data.csv: The Inheritance 1962
# This was written to movie_data.csv: The Inheritance 1976
# This was written to movie_data.csv: The Inheritance 2003
# This was written to movie_data.csv: The Inheritance 2011
# This was written to movie_data.csv: The Inheritance or Fuckoffguysgoodday 1992
# This was written to movie_data.csv: The Inheritors 1998
# This was written to movie_data.csv: The Initiation 1984
# This was written to movie_data.csv: The Initiation of Sarah 1978
# This was written to movie_data.csv: The Initiation of Sarah 2006
# This was written to movie_data.csv: The Inkwell 1994
# This was written to movie_data.csv: The Inn of the Sixth Happiness 1958
# This was written to movie_data.csv: The Inner Circle 1991
# This was written to movie_data.csv: The Inner Life of Martin Frost 2007
# This was written to movie_data.csv: The Inner Scar 1972
# This was written to movie_data.csv: The Innkeepers 2011
# This was written to movie_data.csv: The Innocent 1976
# This was written to movie_data.csv: The Innocent 1993
# This was written to movie_data.csv: The Innocent Sleep 1996
# This was written to movie_data.csv: The Innocents 1961
# This was written to movie_data.csv: The Innocents 1987
# This was written to movie_data.csv: The Innocents 2016
# This was written to movie_data.csv: The Inquisitor 1981
# This was written to movie_data.csv: The Insatiable 2006
# This was written to movie_data.csv: The Insect Woman 1963
# This was written to movie_data.csv: The Inside Man 1985
# This was written to movie_data.csv: The Inside of the White Slave Traffic 1913
# This was written to movie_data.csv: The Insider 1999
# This was written to movie_data.csv: The Inspection 2022
# This was written to movie_data.csv: The Inspector 1962
# This was written to movie_data.csv: The Inspector General 1949
# This was written to movie_data.csv: The Inspectors 1998
# This was written to movie_data.csv: The Institute 2013
# This was written to movie_data.csv: The Intended 2002
# This was written to movie_data.csv: The Interceptor 2009
# This was written to movie_data.csv: The Interior 2015
# This was written to movie_data.csv: The Intern 2000
# This was written to movie_data.csv: The Intern 2015
# This was written to movie_data.csv: The International 2009
# This was written to movie_data.csv: The Internecine Project 1974
# This was written to movie_data.csv: The Internet's Own Boy: The Story of Aaron Swartz 2014
# This was written to movie_data.csv: The Internship 2013
# This was written to movie_data.csv: The Interpreter 2005
# This was written to movie_data.csv: The Interrogation 2009
# This was written to movie_data.csv: The Interrupters 2011
# This was written to movie_data.csv: The Intervention 2016
# This was written to movie_data.csv: The Interview 1998
# This was written to movie_data.csv: The Interview 2014
# This was written to movie_data.csv: The Intimate Stranger 1956
# This was written to movie_data.csv: The Intouchables 2011
# This was written to movie_data.csv: The Intruder 1962
# This was written to movie_data.csv: The Intruder 1999
# This was written to movie_data.csv: The Intruder 2005
# This was written to movie_data.csv: The Intruder 2010
# This was written to movie_data.csv: The Intruder 2019
# This was written to movie_data.csv: The Intruders 2015
# This was written to movie_data.csv: The Invader 2011
# This was written to movie_data.csv: The Invasion 2007
# This was written to movie_data.csv: The Invention of Lying 2009
# This was written to movie_data.csv: The Inventor 2023
# This was written to movie_data.csv: The Investigator 2008
# This was written to movie_data.csv: The Invicible Cell 2009
# This was written to movie_data.csv: The Invincible 2008
# This was written to movie_data.csv: The Invincible Armour 1977
# This was written to movie_data.csv: The Invincible Iron Man 2007
# This was written to movie_data.csv: The Invincible Masked Rider 1963
# This was written to movie_data.csv: The Invisible 2007
# This was written to movie_data.csv: The Invisible Boy 1957
# This was written to movie_data.csv: The Invisible Boy 2014
# This was written to movie_data.csv: The Invisible Circus 2001
# This was written to movie_data.csv: The Invisible Eye 2010
# This was written to movie_data.csv: The Invisible Frame 2009
# This was written to movie_data.csv: The Invisible Front 2014
# This was written to movie_data.csv: The Invisible Guardian 2017
# This was written to movie_data.csv: The Invisible Guest 2016
# This was written to movie_data.csv: The Invisible Kid 1988
# This was written to movie_data.csv: The Invisible Man 1933
# This was written to movie_data.csv: The Invisible Man 1984
# This was written to movie_data.csv: The Invisible Man 2020
# This was written to movie_data.csv: The Invisible Man Returns 1940
# This was written to movie_data.csv: The Invisible Man's Revenge 1944
# This was written to movie_data.csv: The Invisible Maniac 1990
# This was written to movie_data.csv: The Invisible Men 2012
# This was written to movie_data.csv: The Invisible Menace 1938
# This was written to movie_data.csv: The Invisible Ones 2012
# This was written to movie_data.csv: The Invisible Ray 1936
# This was written to movie_data.csv: The Invisible War 2012
# This was written to movie_data.csv: The Invisible Woman 1940
# This was written to movie_data.csv: The Invisible Woman 2009
# This was written to movie_data.csv: The Invisible Woman 2013
# This was written to movie_data.csv: The Invitation 2003
# This was written to movie_data.csv: The Invitation 2015
# This was written to movie_data.csv: The Invitation 2016
# This was written to movie_data.csv: The Invitation 2022
# This was written to movie_data.csv: The Invited 2010
# This was written to movie_data.csv: The Invoking 2013
# This was written to movie_data.csv: The Invoking 2 2015
# This was written to movie_data.csv: The Ipcress File 1965
# This was written to movie_data.csv: The Iran Job 2012
# This was written to movie_data.csv: The Irish Pub 2013
# This was written to movie_data.csv: The Irishman 2019
# This was written to movie_data.csv: The Iron Claw 2023
# This was written to movie_data.csv: The Iron Commissioner 1978
# This was written to movie_data.csv: The Iron Giant 1999
# This was written to movie_data.csv: The Iron Glove 1954
# This was written to movie_data.csv: The Iron Horse 1924
# This was written to movie_data.csv: The Iron Ivan 2014
# This was written to movie_data.csv: The Iron Ladies 2000
# This was written to movie_data.csv: The Iron Lady 2011
# This was written to movie_data.csv: The Iron Mask 1929
# This was written to movie_data.csv: The Iron Ministry 2014
# This was written to movie_data.csv: The Iron Mistress 1952
# This was written to movie_data.csv: The Iron Petticoat 1957
# This was written to movie_data.csv: The Iron Rose 1973
# This was written to movie_data.csv: The Iron Sheriff 1957
# This was written to movie_data.csv: The Irony of Fate, or Enjoy Your Bath! 1975
# This was written to movie_data.csv: The Irony of Fate. The Sequel 2007
# This was written to movie_data.csv: The Irrefutable Truth About Demons 2000
# This was written to movie_data.csv: The Irresistible Blueberry Farm 2016
# This was written to movie_data.csv: The Island 1980
# This was written to movie_data.csv: The Island 2005
# This was written to movie_data.csv: The Island 2006
# This was written to movie_data.csv: The Island 2009
# This was written to movie_data.csv: The Island
# This was written to movie_data.csv: The Island 2: The Hunt for the Lost Treasure 2011
# This was written to movie_data.csv: The Island President 2012
# This was written to movie_data.csv: The Island at the Top of the World 1974
# This was written to movie_data.csv: The Island of Dr. Moreau 1977
# This was written to movie_data.csv: The Island of Dr. Moreau 1996
# This was written to movie_data.csv: The Isle 2000
# This was written to movie_data.csv: The Isle of Lost Ships 1987
# This was written to movie_data.csv: The Issa Valley 1982
# This was written to movie_data.csv: The Italian 1915
# This was written to movie_data.csv: The Italian 2005
# This was written to movie_data.csv: The Italian 2010
# This was written to movie_data.csv: The Italian Connection 1972
# This was written to movie_data.csv: The Italian Job 1969
# This was written to movie_data.csv: The Italian Job 2003
# This was written to movie_data.csv: The Italian Key 2011
# This was written to movie_data.csv: The Italian Straw Hat 1928
# This was written to movie_data.csv: The Item 1999
# This was written to movie_data.csv: The Ivana Trump Story: The First Wife 2022
# This was written to movie_data.csv: The Ivory Game 2016
# This was written to movie_data.csv: The J Team 2021
# This was written to movie_data.csv: The Jack Bull 1999
# This was written to movie_data.csv: The Jackal 1997
# This was written to movie_data.csv: The Jacket 2005
# This was written to movie_data.csv: The Jackie Robinson Story 1950
# This was written to movie_data.csv: The Jackpot 1950
# This was written to movie_data.csv: The Jackpot! 1991
# This was written to movie_data.csv: The Jacksons: An American Dream 1992
# This was written to movie_data.csv: The Jade Mask 1945
# This was written to movie_data.csv: The James Dean Story 1957
# This was written to movie_data.csv: The Jammed 2007
# This was written to movie_data.csv: The Jane Austen Book Club 2007
# This was written to movie_data.csv: The Jane Austen Book Club  2007
# This was written to movie_data.csv: The Janson Directive
# This was written to movie_data.csv: The January Man 1989
# This was written to movie_data.csv: The Jar 1994
# This was written to movie_data.csv: The Jayne Mansfield Story 1980
# This was written to movie_data.csv: The Jazz Loft According to W. Eugene Smith 2016
# This was written to movie_data.csv: The Jazz Singer 1927
# This was written to movie_data.csv: The Jazz Singer 1980
# This was written to movie_data.csv: The Jeffrey Dahmer Files 2013
# This was written to movie_data.csv: The Jericho Mile 1979
# This was written to movie_data.csv: The Jerk 1979
# This was written to movie_data.csv: The Jerk Theory 2008
# This was written to movie_data.csv: The Jerk Theory 2009
# This was written to movie_data.csv: The Jerky Boys 1995
# This was written to movie_data.csv: The Jerky Boys: The Movie 1995
# This was written to movie_data.csv: The Jesse Owens Story 1984
# This was written to movie_data.csv: The Jester's Tale 1964
# This was written to movie_data.csv: The Jesus Film 1979
# This was written to movie_data.csv: The Jesus Music 2021
# This was written to movie_data.csv: The Jetsons Meet the Flintstones 1987
# This was written to movie_data.csv: The Jewel 2011
# This was written to movie_data.csv: The Jewel Thief 2023
# This was written to movie_data.csv: The Jewel of the Nile 1985
# This was written to movie_data.csv: The Jewish Cardinal 2013
# This was written to movie_data.csv: The Jigsaw Man 1984
# This was written to movie_data.csv: The Jimmy Show 2002
# This was written to movie_data.csv: The Jinx: The Life and Deaths of Robert Durst 2015
# This was written to movie_data.csv: The Job 2009
# This was written to movie_data.csv: The Jodorowsky Constellation 1994
# This was written to movie_data.csv: The John Garfield Story 2003
# This was written to movie_data.csv: The Joke 1969
# This was written to movie_data.csv: The Joker Is Wild 1957
# This was written to movie_data.csv: The Jolson Story 1946
# This was written to movie_data.csv: The Joneses 2009
# This was written to movie_data.csv: The Joneses 2010
# This was written to movie_data.csv: The Josephine Baker Story 1991
# This was written to movie_data.csv: The Journey 1959
# This was written to movie_data.csv: The Journey 1992
# This was written to movie_data.csv: The Journey 1997
# This was written to movie_data.csv: The Journey 2001
# This was written to movie_data.csv: The Journey 2014
# This was written to movie_data.csv: The Journey 2017
# This was written to movie_data.csv: The Journey of August King 1995
# This was written to movie_data.csv: The Journey of Natty Gann 1985
# This was written to movie_data.csv: The Journey to Melonia 1989
# This was written to movie_data.csv: The Journey: A Music Special from Andrea Bocelli 2023
# This was written to movie_data.csv: The Joy Luck Club 1993
# This was written to movie_data.csv: The Joy of Living 1961
# This was written to movie_data.csv: The Joyless Street 1925
# This was written to movie_data.csv: The Joyriders 1999
# This was written to movie_data.csv: The Juche Idea 2008
# This was written to movie_data.csv: The Judge 2014
# This was written to movie_data.csv: The Judge Steps Out 1947
# This was written to movie_data.csv: The Judge and the Assassin 1976
# This was written to movie_data.csv: The Judgement 2014
# This was written to movie_data.csv: The Jungle 2012
# This was written to movie_data.csv: The Jungle 2013
# This was written to movie_data.csv: The Jungle Book 1967
# This was written to movie_data.csv: The Jungle Book 1994
# This was written to movie_data.csv: The Jungle Book 2016
# This was written to movie_data.csv: The Jungle Book 2 2003
# This was written to movie_data.csv: The Jungle Book: Mowgli's Story 1998
# This was written to movie_data.csv: The Junkman 1982
# This was written to movie_data.csv: The Juror 1996
# This was written to movie_data.csv: The Kaiser's Lackey 1951
# This was written to movie_data.csv: The Karamazov Brothers 2008
# This was written to movie_data.csv: The Karate Dog 2004
# This was written to movie_data.csv: The Karate Kid 1984
# This was written to movie_data.csv: The Karate Kid 2010
# This was written to movie_data.csv: The Karate Kid Part II 1986
# This was written to movie_data.csv: The Karate Kid Part III 1989
# This was written to movie_data.csv: The Karate Kid, Part II 1986
# This was written to movie_data.csv: The Karate Kid, Part III 1989
# This was written to movie_data.csv: The Kardashians 2022
# This was written to movie_data.csv: The Karen Carpenter Story 1989
# This was written to movie_data.csv: The Karlsson Brothers 2010
# This was written to movie_data.csv: The Kashmir Files 2022
# This was written to movie_data.csv: The Kautokeino Rebellion 2008
# This was written to movie_data.csv: The Keep 1983
# This was written to movie_data.csv: The Keeper 1995
# This was written to movie_data.csv: The Keeper 2004
# This was written to movie_data.csv: The Keeper 2009
# This was written to movie_data.csv: The Keeper of Lost Causes 2013
# This was written to movie_data.csv: The Keeper: The Legend of Omar Khayyam 2005
# This was written to movie_data.csv: The Keepers 2017
# This was written to movie_data.csv: The Keeping Room 2014
# This was written to movie_data.csv: The Kennedys 2011
# This was written to movie_data.csv: The Kentuckian 1955
# This was written to movie_data.csv: The Kentucky Fried Movie 1977
# This was written to movie_data.csv: The Ketchup Effect 2004
# This was written to movie_data.csv: The Key 1934
# This was written to movie_data.csv: The Key 1958
# This was written to movie_data.csv: The Key 1983
# This was written to movie_data.csv: The Key to Paradise 1970
# This was written to movie_data.csv: The Key to Reserva (La clave Reserva) 2007
# This was written to movie_data.csv: The Keys of the Kingdom 1944
# This was written to movie_data.csv: The Keys to the House 2004
# This was written to movie_data.csv: The Keys to the Street
# This was written to movie_data.csv: The Kick 2011
# This was written to movie_data.csv: The Kid 1921
# This was written to movie_data.csv: The Kid 2000
# This was written to movie_data.csv: The Kid 2019
# This was written to movie_data.csv: The Kid & I 2005
# This was written to movie_data.csv: The Kid Brother 1927
# This was written to movie_data.csv: The Kid Detective 2020
# This was written to movie_data.csv: The Kid Stays in the Picture 2002
# This was written to movie_data.csv: The Kid Who Would Be King 2019
# This was written to movie_data.csv: The Kid from Brooklyn 1946
# This was written to movie_data.csv: The Kid with a Bike 2011
# This was written to movie_data.csv: The Kidnappers 1953
# This was written to movie_data.csv: The Kidnapping Of The President 1980
# This was written to movie_data.csv: The Kidnapping of Michel Houellebecq 2014
# This was written to movie_data.csv: The Kidnapping of the President 1980
# This was written to movie_data.csv: The Kids 1957
# This was written to movie_data.csv: The Kids Are All Right 2010
# This was written to movie_data.csv: The Kids Are Alright 1979
# This was written to movie_data.csv: The Kill Hole 2012
# This was written to movie_data.csv: The Kill Room 2023
# This was written to movie_data.csv: The Kill Team 2013
# This was written to movie_data.csv: The Kill Team 2019
# This was written to movie_data.csv: The Killer 1989
# This was written to movie_data.csv: The Killer 2023
# This was written to movie_data.csv: The Killer Elite 1975
# This was written to movie_data.csv: The Killer Inside Me 1976
# This was written to movie_data.csv: The Killer Inside Me 2010
# This was written to movie_data.csv: The Killer Is Loose 1956
# This was written to movie_data.csv: The Killer Meteors 1976
# This was written to movie_data.csv: The Killer Must Kill Again 1975
# This was written to movie_data.csv: The Killer Shrews 1959
# This was written to movie_data.csv: The Killer Wore Gloves 1974
# This was written to movie_data.csv: The Killers 1946
# This was written to movie_data.csv: The Killers 1956
# This was written to movie_data.csv: The Killers 1964
# This was written to movie_data.csv: The Killing 1956
# This was written to movie_data.csv: The Killing Fields 1984
# This was written to movie_data.csv: The Killing Floor 2007
# This was written to movie_data.csv: The Killing Game 2011
# This was written to movie_data.csv: The Killing Gene 2007
# This was written to movie_data.csv: The Killing Jar 2010
# This was written to movie_data.csv: The Killing Machine 1995
# This was written to movie_data.csv: The Killing Room 2009
# This was written to movie_data.csv: The Killing of America 1981
# This was written to movie_data.csv: The Killing of John Lennon 2007
# This was written to movie_data.csv: The Killing of John Lennon 2008
# This was written to movie_data.csv: The Killing of Kenneth Chamberlain 2021
# This was written to movie_data.csv: The Killing of Satan 1983
# This was written to movie_data.csv: The Killing of Sister George 1968
# This was written to movie_data.csv: The Killing of Two Lovers 2021
# This was written to movie_data.csv: The Killing of a Chinese Bookie 1976
# This was written to movie_data.csv: The Killing of a Sacred Deer 2017
# This was written to movie_data.csv: The Killings at Outpost Zeta 1980
# This was written to movie_data.csv: The Kind One
# This was written to movie_data.csv: The Kind Words 2015
# This was written to movie_data.csv: The Kindergarten Teacher 2014
# This was written to movie_data.csv: The Kindergarten Teacher 2018
# This was written to movie_data.csv: The Kindness of Strangers 2020
# This was written to movie_data.csv: The Kindred 1987
# This was written to movie_data.csv: The Kinematograph 2009
# This was written to movie_data.csv: The King 2002
# This was written to movie_data.csv: The King 2005
# This was written to movie_data.csv: The King 2017
# This was written to movie_data.csv: The King 2019
# This was written to movie_data.csv: The King Is Alive 2000
# This was written to movie_data.csv: The King Is Alive 2001
# This was written to movie_data.csv: The King Is Dancing 2000
# This was written to movie_data.csv: The King Is Dead! 2012
# This was written to movie_data.csv: The King and Four Queens 1956
# This was written to movie_data.csv: The King and I 1956
# This was written to movie_data.csv: The King and I 1999
# This was written to movie_data.csv: The King and Queen of Moonlight Bay 2003
# This was written to movie_data.csv: The King and the Mockingbird 1980
# This was written to movie_data.csv: The King of Arcades 2014
# This was written to movie_data.csv: The King of Comedy 1982
# This was written to movie_data.csv: The King of Escape 2009
# This was written to movie_data.csv: The King of Fighters 2009
# This was written to movie_data.csv: The King of Havana 2015
# This was written to movie_data.csv: The King of Kings 1927
# This was written to movie_data.csv: The King of Kong 2007
# This was written to movie_data.csv: The King of Kong: A Fistful of Quarters 2007
# This was written to movie_data.csv: The King of Marvin Gardens 1972
# This was written to movie_data.csv: The King of Masks 1997
# This was written to movie_data.csv: The King of Pigs 2011
# This was written to movie_data.csv: The King of Ping Pong 2008
# This was written to movie_data.csv: The King of Staten Island 2020
# This was written to movie_data.csv: The King of Texas 2008
# This was written to movie_data.csv: The King of the Kickboxers 1990
# This was written to movie_data.csv: The King's Beard 2002
# This was written to movie_data.csv: The King's Choice 2016
# This was written to movie_data.csv: The King's Daughter 2022
# This was written to movie_data.csv: The King's Man 2021
# This was written to movie_data.csv: The King's Speech 2010
# This was written to movie_data.csv: The King's Whore 1990
# This was written to movie_data.csv: The Kingdom 1994
# This was written to movie_data.csv: The Kingdom 2007
# This was written to movie_data.csv: The Kingdom II 1997
# This was written to movie_data.csv: The Kingdom of Diamonds 1980
# This was written to movie_data.csv: The Kingdom of Dreams and Madness 2013
# This was written to movie_data.csv: The Kingdom of Fairies 1903
# This was written to movie_data.csv: The Kingdom of Solomon 2010
# This was written to movie_data.csv: The Kings of Mykonos 2010
# This was written to movie_data.csv: The Kings of Summer 2013
# This was written to movie_data.csv: The Kirlian Witness 1979
# This was written to movie_data.csv: The Kiss 1896
# This was written to movie_data.csv: The Kiss 1900
# This was written to movie_data.csv: The Kiss 1929
# This was written to movie_data.csv: The Kiss 1988
# This was written to movie_data.csv: The Kiss 2004
# This was written to movie_data.csv: The Kiss of Her Flesh 1968
# This was written to movie_data.csv: The Kiss of the Vampire 1963
# This was written to movie_data.csv: The Kissing Booth 2018
# This was written to movie_data.csv: The Kissing Booth 2 2020
# This was written to movie_data.csv: The Kissing Booth 3 2021
# This was written to movie_data.csv: The Kitchen 2012
# This was written to movie_data.csv: The Kitchen 2019
# This was written to movie_data.csv: The Kitchen 2023
# This was written to movie_data.csv: The Kite Runner 2007
# This was written to movie_data.csv: The Kiyosu Conference 2013
# This was written to movie_data.csv: The Klansman 1974
# This was written to movie_data.csv: The Knack... and How to Get It 1965
# This was written to movie_data.csv: The Knight Before Christmas 2019
# This was written to movie_data.csv: The Knock Out Cop 1973
# This was written to movie_data.csv: The Knockout 1914
# This was written to movie_data.csv: The Knot 2000
# This was written to movie_data.csv: The Knot 2012
# This was written to movie_data.csv: The Kodai Family 2016
# This was written to movie_data.csv: The Kollective
# This was written to movie_data.csv: The Kopeck 2002
# This was written to movie_data.csv: The Koumiko Mystery 1965
# This was written to movie_data.csv: The Krays 1990
# This was written to movie_data.csv: The Kremlin Letter 1970
# This was written to movie_data.csv: The Kreutzer Sonata 2008
# This was written to movie_data.csv: The Ku Klux Klan: A Secret History 1998
# This was written to movie_data.csv: The Kung Fu Instructor 1979
# This was written to movie_data.csv: The L-Shaped Room 1962
# This was written to movie_data.csv: The Laboratory of Fear 1971
# This was written to movie_data.csv: The Lacemaker 1977
# This was written to movie_data.csv: The Ladies Man 1961
# This was written to movie_data.csv: The Ladies Man 2000
# This was written to movie_data.csv: The Ladies of the House 2014
# This was written to movie_data.csv: The Lady 2011
# This was written to movie_data.csv: The Lady Bird Diaries 2023
# This was written to movie_data.csv: The Lady Eve 1941
# This was written to movie_data.csv: The Lady Is Willing 1942
# This was written to movie_data.csv: The Lady Says No 1952
# This was written to movie_data.csv: The Lady Vanishes 1938
# This was written to movie_data.csv: The Lady Vanishes 1979
# This was written to movie_data.csv: The Lady Vanishes 2013
# This was written to movie_data.csv: The Lady Without Camelias 1953
# This was written to movie_data.csv: The Lady and the Duke 2001
# This was written to movie_data.csv: The Lady and the Duke 2002
# This was written to movie_data.csv: The Lady and the Highwayman 1989
# This was written to movie_data.csv: The Lady and the Reaper 2009
# This was written to movie_data.csv: The Lady from Shanghai 1947
# This was written to movie_data.csv: The Lady in Number 6 2013
# This was written to movie_data.csv: The Lady in Question 1940
# This was written to movie_data.csv: The Lady in Question Is Charles Busch 2005
# This was written to movie_data.csv: The Lady in Red 1979
# This was written to movie_data.csv: The Lady in the Car with Glasses and a Gun 1970
# This was written to movie_data.csv: The Lady in the Car with Glasses and a Gun 2015
# This was written to movie_data.csv: The Lady in the Van 2015
# This was written to movie_data.csv: The Lady of Heaven 2021
# This was written to movie_data.csv: The Lady of Scandal 1930
# This was written to movie_data.csv: The Ladykillers 1955
# This was written to movie_data.csv: The Ladykillers 2004
# This was written to movie_data.csv: The Lair of the White Worm 1988
# This was written to movie_data.csv: The Lake House 2006
# This was written to movie_data.csv: The Land 1942
# This was written to movie_data.csv: The Land 1969
# This was written to movie_data.csv: The Land 2016
# This was written to movie_data.csv: The Land Before Time 1988
# This was written to movie_data.csv: The Land Before Time II: The Great Valley Adventure 1994
# This was written to movie_data.csv: The Land Before Time III: The Time of the Great Giving 1995
# This was written to movie_data.csv: The Land Before Time IV: Journey Through the Mists 1996
# This was written to movie_data.csv: The Land Before Time IX: Journey to the Big Water 2002
# This was written to movie_data.csv: The Land Before Time V: The Mysterious Island 1997
# This was written to movie_data.csv: The Land Before Time VI: The Secret of Saurus Rock 1998
# This was written to movie_data.csv: The Land Before Time VII: The Stone of Cold Fire 2000
# This was written to movie_data.csv: The Land Before Time VIII: The Big Freeze 2001
# ...
# This was written to movie_data.csv: Zapatlela 2 2013
# This was written to movie_data.csv: Zappa 1983
# This was written to movie_data.csv: Zappa Plays Zappa 2007
# This was written to movie_data.csv: Zapped 2014
# This was written to movie_data.csv: Zapped Again! 1990
# This was written to movie_data.csv: Zapped! 1982
# This was written to movie_data.csv: Zarafa 2012
# This was written to movie_data.csv: Zardoz 1974
# This was written to movie_data.csv: Zarkorr! The Invader 1996
# This was written to movie_data.csv: Zathura 2005
# This was written to movie_data.csv: Zathura: A Space Adventure 2005
# This was written to movie_data.csv: Zatoichi 2003
# This was written to movie_data.csv: Zatôichi Challenged 1967
# This was written to movie_data.csv: Zatôichi Goes to the Fire Festival 1970
# This was written to movie_data.csv: Zatôichi Meets Yojimbo 1970
# This was written to movie_data.csv: Zatôichi Meets the One-Armed Swordsman 1971
# This was written to movie_data.csv: Zatôichi and the Chess Expert 1965
# This was written to movie_data.csv: Zatôichi and the Chest of Gold 1964
# This was written to movie_data.csv: Zatôichi and the Doomed Man 1965
# This was written to movie_data.csv: Zatôichi and the Fugitives 1968
# This was written to movie_data.csv: Zatôichi at Large 1972
# This was written to movie_data.csv: Zatôichi in Desperation 1972
# This was written to movie_data.csv: Zatôichi on the Road 1963
# This was written to movie_data.csv: Zatôichi the Fugitive 1963
# This was written to movie_data.csv: Zatôichi the Outlaw 1967
# This was written to movie_data.csv: Zatôichi's Cane Sword 1967
# This was written to movie_data.csv: Zatôichi's Conspiracy 1973
# This was written to movie_data.csv: Zatôichi's Flashing Sword 1964
# This was written to movie_data.csv: Zatôichi's Pilgrimage 1966
# This was written to movie_data.csv: Zatôichi's Revenge 1965
# This was written to movie_data.csv: Zatôichi's Vengeance 1966
# This was written to movie_data.csv: Zatôichi: The Blind Swordsman 1989
# This was written to movie_data.csv: Zaytoun 2012
# This was written to movie_data.csv: Zaza 1938
# This was written to movie_data.csv: Zazie dans le métro 1960
# This was written to movie_data.csv: Zebra 2016
# This was written to movie_data.csv: Zebra Lounge 2001
# This was written to movie_data.csv: Zebra in the Kitchen 1965
# This was written to movie_data.csv: Zebrahead 1992
# This was written to movie_data.csv: Zebraman 2004
# This was written to movie_data.csv: Zeder 1983
# This was written to movie_data.csv: Zeher 2005
# This was written to movie_data.csv: Zeitgeist 2007
# This was written to movie_data.csv: Zeitgeist: Addendum 2008
# This was written to movie_data.csv: Zeitgeist: Moving Forward 2011
# This was written to movie_data.csv: Zelig 1983
# This was written to movie_data.csv: Zen 2009
# This was written to movie_data.csv: Zen Noir 2004
# This was written to movie_data.csv: Zenda 2009
# This was written to movie_data.csv: Zenith 2010
# This was written to movie_data.csv: Zenobia 1939
# This was written to movie_data.csv: Zenon: Girl of the 21st Century 1999
# This was written to movie_data.csv: Zenon: The Zequel 2001
# This was written to movie_data.csv: Zenon: Z3 2004
# This was written to movie_data.csv: Zentropa 1992
# This was written to movie_data.csv: Zephyr Springs 2013
# This was written to movie_data.csv: Zeppelin 1971
# This was written to movie_data.csv: Zero 2012
# This was written to movie_data.csv: Zero 2015
# This was written to movie_data.csv: Zero 2 2010
# This was written to movie_data.csv: Zero 3 2017
# This was written to movie_data.csv: Zero Bridge 2011
# This was written to movie_data.csv: Zero Charisma 2013
# This was written to movie_data.csv: Zero Contact 2022
# This was written to movie_data.csv: Zero Dark Thirty 2012
# This was written to movie_data.csv: Zero Day 2002
# This was written to movie_data.csv: Zero Day 2003
# This was written to movie_data.csv: Zero Days 2016
# This was written to movie_data.csv: Zero Effect 1998
# This was written to movie_data.csv: Zero Focus 1961
# This was written to movie_data.csv: Zero Hour! 1957
# This was written to movie_data.csv: Zero Kelvin 1995
# This was written to movie_data.csv: Zero Motivation 2014
# This was written to movie_data.csv: Zero Tolerance 1999
# This was written to movie_data.csv: Zero Woman: Red Handcuffs 1974
# This was written to movie_data.csv: Zero for Conduct 1933
# This was written to movie_data.csv: Zero to Sixty 1978
# This was written to movie_data.csv: Zero. Lilac Lithuania 2006
# This was written to movie_data.csv: Zerophillia 2005
# This was written to movie_data.csv: Zeros and Ones 2021
# This was written to movie_data.csv: Zeroville 2019
# This was written to movie_data.csv: Zeta One 1969
# This was written to movie_data.csv: Zettl 2012
# This was written to movie_data.csv: Zeus & Roxanne 1997
# This was written to movie_data.csv: Zeus and Roxanne 1997
# This was written to movie_data.csv: Zhit 2010
# This was written to movie_data.csv: Zhongkui: Snow Girl and the Dark Crystal 2015
# This was written to movie_data.csv: Zhou Yu's Train 2002
# This was written to movie_data.csv: Zid 2014
# This was written to movie_data.csv: Zidane - A 21st Century Portrait 2006
# This was written to movie_data.csv: Ziegfeld Follies 1945
# This was written to movie_data.csv: Zift 2008
# This was written to movie_data.csv: Zig Zag 1970
# This was written to movie_data.csv: Zig Zag 2002
# This was written to movie_data.csv: Zig Zag Story 1983
# This was written to movie_data.csv: Zigeunerweisen 1980
# This was written to movie_data.csv: Ziggy  Stardust and the Spiders from Mars 1973
# This was written to movie_data.csv: Zigzag of Success 1968
# This was written to movie_data.csv: Zincirbozan 2007
# This was written to movie_data.csv: Zindagi Na Milegi Dobara 2011
# This was written to movie_data.csv: Zip & Zap and the Captain's Island 2016
# This was written to movie_data.csv: Zipper 2015
# This was written to movie_data.csv: Zodiac 2007
# This was written to movie_data.csv: Zodiac 2014
# This was written to movie_data.csv: Zoey 102 2023
# This was written to movie_data.csv: Zola 2021
# This was written to movie_data.csv: Zombeak 2006
# This was written to movie_data.csv: Zombeavers 2014
# This was written to movie_data.csv: Zombi 2 1981
# This was written to movie_data.csv: Zombie 1979
# This was written to movie_data.csv: Zombie Apocalypse 2011
# This was written to movie_data.csv: Zombie Ass: Toilet of the Dead 2011
# This was written to movie_data.csv: Zombie Christ 2010
# This was written to movie_data.csv: Zombie Diaries 2006
# This was written to movie_data.csv: Zombie Fever 2013
# This was written to movie_data.csv: Zombie Flesh Eaters 1979
# This was written to movie_data.csv: Zombie Girl: The Movie 2009
# This was written to movie_data.csv: Zombie High 1987
# This was written to movie_data.csv: Zombie Holocaust 1980
# This was written to movie_data.csv: Zombie Honeymoon 2004
# This was written to movie_data.csv: Zombie Island Massacre 1984
# This was written to movie_data.csv: Zombie Lake 1981
# This was written to movie_data.csv: Zombie Night 2013
# This was written to movie_data.csv: Zombie Nightmare 1987
# This was written to movie_data.csv: Zombie Ninjas vs Black Ops 2015
# This was written to movie_data.csv: Zombie Pizza 2017
# This was written to movie_data.csv: Zombie Reanimation 2009
# This was written to movie_data.csv: Zombie Resurrection 2014
# This was written to movie_data.csv: Zombie Strippers 2008
# This was written to movie_data.csv: Zombie Strippers! 2008
# This was written to movie_data.csv: Zombie Undead 2010
# This was written to movie_data.csv: Zombie Wars 2006
# This was written to movie_data.csv: Zombie and the Ghost Train 1991
# This was written to movie_data.csv: Zombieland 2009
# This was written to movie_data.csv: Zombieland 2013
# This was written to movie_data.csv: Zombieland: Double Tap 2019
# This was written to movie_data.csv: Zombies 3 2022
# This was written to movie_data.csv: Zombies of Mora Tau 1957
# This was written to movie_data.csv: Zombies of the Stratosphere 1952
# This was written to movie_data.csv: Zombies on Broadway 1945
# This was written to movie_data.csv: Zombies! Zombies! Zombies! 2008
# This was written to movie_data.csv: Zombies: The Beginning 2007
# This was written to movie_data.csv: Zombieworld 2015
# This was written to movie_data.csv: Zomboat! 2019
# This was written to movie_data.csv: Zone 39 1996
# This was written to movie_data.csv: Zone Troopers 1985
# This was written to movie_data.csv: Zone of the Dead 2009
# This was written to movie_data.csv: Zone of the Enders: Idolo 2001
# This was written to movie_data.csv: Zoo 2007
# This was written to movie_data.csv: Zoo in Budapest 1933
# This was written to movie_data.csv: Zookeeper 2011
# This was written to movie_data.csv: Zoolander 2001
# This was written to movie_data.csv: Zoolander 2 2016
# This was written to movie_data.csv: Zoology 2016
# This was written to movie_data.csv: Zoom 2006
# This was written to movie_data.csv: Zoom 2015
# This was written to movie_data.csv: Zoombies 2016
# This was written to movie_data.csv: Zoot Suit 1981
# This was written to movie_data.csv: Zootopia 2016
# This was written to movie_data.csv: Zoran, il mio nipote scemo 2013
# This was written to movie_data.csv: Zorba the Greek 1964
# This was written to movie_data.csv: Zorns Lemma 1970
# This was written to movie_data.csv: Zorro 1975
# This was written to movie_data.csv: Zorro, The Gay Blade 1981
# This was written to movie_data.csv: Zorro: The Gay Blade 1981
# This was written to movie_data.csv: Zotz! 1962
# This was written to movie_data.csv: Zozo 2005
# This was written to movie_data.csv: Zróbmy sobie wnuka 2003
# This was written to movie_data.csv: Zu: Warriors from the Magic Mountain 1983
# This was written to movie_data.csv: Zulu 1964
# This was written to movie_data.csv: Zulu 2013
# This was written to movie_data.csv: Zulu Dawn 1979
# This was written to movie_data.csv: Zurich 2015
# This was written to movie_data.csv: Zus & Zo 2001
# This was written to movie_data.csv: Zuzu Angel 2006
# This was written to movie_data.csv: Zvenigora 1928
# This was written to movie_data.csv: Zygote 2017
# This was written to movie_data.csv: Zyzzyx Road 2006
# This was written to movie_data.csv: Zézero 1974
# This was written to movie_data.csv: [REC] 2007
# This was written to movie_data.csv: [REC]² 2009
# This was written to movie_data.csv: [REC]³ Genesis 2012
# This was written to movie_data.csv: [REC]⁴ Apocalypse 2014
# This was written to movie_data.csv: a/k/a Tommy Chong 2006
# This was written to movie_data.csv: alaskaLand 2013
# This was written to movie_data.csv: differently, Molussia 2012
# This was written to movie_data.csv: e-motion 2013
# This was written to movie_data.csv: eCupid 2011
# This was written to movie_data.csv: eXistenZ 1999
# This was written to movie_data.csv: g@me. 2003
# This was written to movie_data.csv: i hate myself :) 2013
# This was written to movie_data.csv: iBoy 2017
# This was written to movie_data.csv: iGirl 2016
# This was written to movie_data.csv: iMurders 2008
# This was written to movie_data.csv: iNumber Number 2013
# This was written to movie_data.csv: iNumber Number: Jozi Gold 2023
# This was written to movie_data.csv: iSteve 2013
# This was written to movie_data.csv: ivans xtc. 2000
# This was written to movie_data.csv: jazzy@32 (a true story) 2016
# This was written to movie_data.csv: loudQUIETloud: A Film About the Pixies 2006
# This was written to movie_data.csv: natural history 2014
# This was written to movie_data.csv: s/y Glädjen 1989
# This was written to movie_data.csv: scissere 1982
# This was written to movie_data.csv: small roads 2011
# This was written to movie_data.csv: tick, tick... BOOM! 2021
# This was written to movie_data.csv: tzeni tzeni 1966
# This was written to movie_data.csv: unINDIAN 2015
# This was written to movie_data.csv: uwantme2killhim? 2013
# This was written to movie_data.csv: xXx 2002
# This was written to movie_data.csv: xXx: Return of Xander Cage 2017
# This was written to movie_data.csv: xXx: State of the Union 2005
# This was written to movie_data.csv: ¡A mí la legión! 1942
# This was written to movie_data.csv: ¡A volar joven! 1947
# This was written to movie_data.csv: ¡Asu Mare! 2 2015
# This was written to movie_data.csv: ¡Cuba Sí! 1961
# This was written to movie_data.csv: ¡Mátalo! 1970
# This was written to movie_data.csv: ¡Por mis... pistolas! 1968
# This was written to movie_data.csv: ¡Que Viva México! 1979
# This was written to movie_data.csv: ¡Three Amigos! 1986
# This was written to movie_data.csv: ¡Vivan las Antipodas! 2011
# This was written to movie_data.csv: ¿Quién mató a Bambi? 2013
# This was written to movie_data.csv: ¿Y cómo es él? 2022
# This was written to movie_data.csv: À Nous la Liberté 1931
# This was written to movie_data.csv: À l'aventure 2008
# This was written to movie_data.csv: À la mode 1993
# This was written to movie_data.csv: À nos amours 1983
# This was written to movie_data.csv: À propos de Nice 1930
# This was written to movie_data.csv: Ánima Buenos Aires 2012
# This was written to movie_data.csv: Åke and His World 1984
# This was written to movie_data.csv: Åsa-Nisse - Welcome to Knohult 2011
# This was written to movie_data.csv: Æon Flux 2005
# This was written to movie_data.csv: Ça brûle 2006
# This was written to movie_data.csv: Çalgı Çengi 2011
# This was written to movie_data.csv: Çöpçüler Kralı 1977
# This was written to movie_data.csv: È arrivato mio fratello 1985
# This was written to movie_data.csv: Édith et Marcel 1983
# This was written to movie_data.csv: Él 1953
# This was written to movie_data.csv: Ödipussi 1988
# This was written to movie_data.csv: Üvegtigris 2001
# This was written to movie_data.csv: İtirazım Var 2014
# This was written to movie_data.csv: Şaban Oğlu Şaban 1977
# This was written to movie_data.csv: Şabaniye 1984
# This was written to movie_data.csv: Şevkat Yerimdar 2013
# This was written to movie_data.csv: Škola princů 2010
# This was written to movie_data.csv: Šíleně smutná princezna 1968
# This was written to movie_data.csv: Želary 2003
# This was written to movie_data.csv: Žižek! 2005
# This was written to movie_data.csv: Κλέφτες 2007
# This was written to movie_data.csv: Λατέρνα, Φτώχεια και Γαρύφαλλο 1954
# This was written to movie_data.csv: Μαριχουάνα Στοπ ! 1971
# This was written to movie_data.csv: Νόμος 4000 1962
# This was written to movie_data.csv: Ο Θανάσης στη χώρα της σφαλιάρας 1976
# This was written to movie_data.csv: Τέλειοι Ξένοι 2016
# This was written to movie_data.csv: Το Ξύλο Βγήκε Από Τον Παράδεισο 1959
# This was written to movie_data.csv: Το γάλα 2012
# This was written to movie_data.csv: Υπάρχει Και Φιλότιμο 1965
# This was written to movie_data.csv: Іван Сила 2013
# This was written to movie_data.csv: А поутру они проснулись 2003
# This was written to movie_data.csv: Гонгофер 1992
# This was written to movie_data.csv: Ехали в трамвае Ильф и Петров 1972
# This was written to movie_data.csv: Каменная башка 2008
# This was written to movie_data.csv: Карусель 1970
# This was written to movie_data.csv: Кентервильское привидение 1970
# This was written to movie_data.csv: Королёв 2007
# This was written to movie_data.csv: Крепость: щитом и мечом 2015
# This was written to movie_data.csv: Львиная доля 2001
# This was written to movie_data.csv: Медведь 1938
# This was written to movie_data.csv: Оно 1990
# This was written to movie_data.csv: Перекресток 1998
# This was written to movie_data.csv: Поезд вне расписания 1986
# This was written to movie_data.csv: Поэма о крыльях 1979
# This was written to movie_data.csv: Приключения Домовёнка 1986
# This was written to movie_data.csv: Приключения Шерлока Холмса и доктора Ватсона: Двадцатый век начинается 1986
# This was written to movie_data.csv: Путь к себе 2010
# This was written to movie_data.csv: Семь кабинок 2007
# This was written to movie_data.csv: Совершенно серьезно 1961
# This was written to movie_data.csv: Убить дракона 1988
# This was written to movie_data.csv: Юленька 2009
# This was written to movie_data.csv: هیچ کجا هیچ کس 2013
# This was written to movie_data.csv: ‘Rameau’s Nephew’ by Diderot (Thanx to Dennis Young) by Wilma Schoen 1974
# This was written to movie_data.csv: ’Round Midnight 1986
# This was written to movie_data.csv: …And the Fifth Horseman Is Fear 1965
# This was written to movie_data.csv: ファンタスティポ 2005
