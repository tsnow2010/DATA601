# %% [markdown]
# # Create 'movie_data.csv' using Movie.py

# %%
import pandas as pd
from Movie import Movie
import csv
import re

# %% [markdown]
# #### Step 1:
#
# Take list from IMDB of domestic films released from 1972 to 2016 and (7) lists of original movies from streaming services, pull titles and years, and put data in 'movie_year_from_1972_2023.csv'

# %%
# Gets titles and years and writes to 'movie_year_from_1972_2023.csv'

files1 = ['data/us_released_movies_1972_to_2016.csv',
         'data/Streaming Movie Lists/amazon_prime_movie_list.csv',
         'data/Streaming Movie Lists/apple_tv_movie_list.csv',
         'data/Streaming Movie Lists/disney_plus_movie_list.csv',
         'data/Streaming Movie Lists/hbo_movie_list.csv',
         'data/Streaming Movie Lists/hulu_programming_list.csv',
         'data/Streaming Movie Lists/netflix_movie_list.csv',
         'data/Streaming Movie Lists/paramount_plus_movie_list.csv'
        ]
         
Movie.get_titles_from_csv(files1,'movie_year_from_1972_2023.csv')

# %% [markdown]
# #### Step 2:
# Using HTML pages from Box Office Mojo, pull titles and years of domestic films made from 2017 to 2023 to supplement the lists from files1.

# %%
# Below code creates 'movie_year_from_1972_2023.csv' containing title,year of every domestic movie from 1972-2023.

# List of html files of domestic movies by year indicated in name
files2 = ['data/Domestic Movies from 2017-2023/Domestic Box Office For 2017 - Box Office Mojo.txt',
         'data/Domestic Movies from 2017-2023/Domestic Box Office For 2018 - Box Office Mojo.txt',
         'data/Domestic Movies from 2017-2023/Domestic Box Office For 2019 - Box Office Mojo.txt',
         'data/Domestic Movies from 2017-2023/Domestic Box Office For 2020 - Box Office Mojo.txt',
         'data/Domestic Movies from 2017-2023/Domestic Box Office For 2021 - Box Office Mojo.txt',
         'data/Domestic Movies from 2017-2023/Domestic Box Office For 2022 - Box Office Mojo.txt',
         'data/Domestic Movies from 2017-2023/Domestic Box Office For 2023 - Box Office Mojo.txt']

Movie.get_titles_from_html(files2, 'movie_year_from_1972_2023.csv')

# %% [markdown]
# #### Step 3:
# Because the dataset, movie_year_from_1972_2023.csv, contains a lot of duplicates, we now clean the data and remove those duplicates.

# %% [markdown]
# Check for duplicate rows in movie_year_from_1972_2023.csv.

# %%
import pandas as pd
import requests
import json

df = pd.read_csv('movie_year_from_1972_2023.csv')
df[df.duplicated() == True]

# %% [markdown]
# Remove duplicates from movie_year_from_1972_2023.csv and verify removal.

# %%
df_no_dups = df.drop_duplicates()
df_no_dups[df_no_dups.duplicated() == True]

# %%
print("Original Dataset had", df.shape[0],'rows.')
print("Cleaned Dataset has", df_no_dups.shape[0],'rows.')

# %% [markdown]
# Export the pandas dataset to 'no_dups_movie_year_from_1972_2023.xlsx' and remove numerical index manually.

# %%
df_no_dups.to_excel('no_dups_movie_year_from_1972_2023.xlsx')

# %% [markdown]
# #### Step 4:
#
# With no_dups_movie_year_from_1972_2023.csv now containing all domestic movies made from 1972 to 2023, **make_movie_data()** does the following:
#
# * Creates movie_data.csv and writes first row containing column names.
# * Iterates through each row in movie_year_from_1972_2023, requests movie data from (2) APIs, and appends to movie_data.csv.
# * The only parameter is 'start' which is either:
#   * **1 (int)** to start from the beginning of the 'no_dups_movie_year_from_1972_2023.csv' dataset.
#   * **'Movie Title/YearReleased'** to start from the last movie found, as indicated from the bottom of movie_data.csv.
#     * For example, "The Terminator/1984" would be valid input.

# %%
def make_movie_data(start):

    if start == 1:
        # Writes first line of 'movie_data.csv'
        with open('movie_data.csv','w') as file:
            writer = csv.writer(file,delimiter=',')
            writer.writerow(['Title',
                            'Year',
                            'Genre(s)',
                            'IMDB',
                            'Rotten Tomatoes',
                            'Metacritic',
                            'TMDB',
                            '# of IMDB Votes',
                            '# of Awards',
                            'Gross Domestic Box Office Sales ($)',
                            'Media',
                            'Directors',
                            'Origin'])
        
    # Writes the dataset
    with open('no_dups_movie_year_from_1972_2023.csv','r',buffering=1) as file:
        reader = csv.reader(file,delimiter=',')
        
        if start != 1:
            row = next(reader)
            while (row[0] + '/' + row[1] != start):
                row = next(reader)
            for row in reader:
                new_movie = Movie(row[0],row[1])
                new_movie.get_movie_data()
        else:
            header = next(reader)
            for row in reader:
                new_movie = Movie(row[0],row[1])
                new_movie.get_movie_data()

# %% [markdown]
# Below commands invoke make_movie_data().

# %%
# Use below line to "pick up" after last movie pulled from OMDB API
#make_movie_data(1)
make_movie_data('Hobgoblins/1988')
# Out:
# This was written to movie_data.csv: 'Round Midnight 1986
# This was written to movie_data.csv: Bat*21 1988
# This was written to movie_data.csv: Howling II: ... Your Sister Is a Werewolf 1985
# This was written to movie_data.csv: One from the Heart 1981
# This was written to movie_data.csv: Suburbia 1983
# This was written to movie_data.csv: Butterfly 1981
# This was written to movie_data.csv: Liquid Sky 1982
# This was written to movie_data.csv: S.O.B. 1981
# This was written to movie_data.csv: Looker 1981
# This was written to movie_data.csv: Death Hunt 1981
# This was written to movie_data.csv: Under the Rainbow 1981
# This was written to movie_data.csv: BMX Bandits 1983
# This was written to movie_data.csv: Terror Train 1980
# This was written to movie_data.csv: The Private Eyes 1980
# This was written to movie_data.csv: True Confessions 1981
# This was written to movie_data.csv: Raise the Titanic 1980
# This was written to movie_data.csv: Ms .45 1981
# This was written to movie_data.csv: Slave of the Cannibal God 1978
# This was written to movie_data.csv: Felicity 1978
# This was written to movie_data.csv: Starcrash 1978
# This was written to movie_data.csv: Death Bed: The Bed That Eats 1977
# This was written to movie_data.csv: Thank God It's Friday 1978
# This was written to movie_data.csv: Martin 1977
# This was written to movie_data.csv: White Lightning 1973
# This was written to movie_data.csv: Scorpio 1973
# This was written to movie_data.csv: The Life and Times of Judge Roy Bean 1972
# This was written to movie_data.csv: The Pig Keeper's Daughter 1972
# This was written to movie_data.csv: Asylum 1972
# This was written to movie_data.csv: Funny Lady 1975
# This was written to movie_data.csv: Farewell, My Lovely 1975
# This was written to movie_data.csv: Switchblade Sisters 1975
# This was written to movie_data.csv: Dirty Mary Crazy Larry 1974
# This was written to movie_data.csv: Benji 1974
# This was written to movie_data.csv: Ivan Vasilyevich Changes His Profession 1973
# This was written to movie_data.csv: Charley Varrick 1973
# This was written to movie_data.csv: Jonathan Livingston Seagull 1973
# This was written to movie_data.csv: The Mother and the Whore 1973
# This was written to movie_data.csv: O Lucky Man! 1973
# This was written to movie_data.csv: The Killing of a Chinese Bookie 1976
# This was written to movie_data.csv: The Turning Point 1977
# This was written to movie_data.csv: March or Die 1977
# This was written to movie_data.csv: The American Friend 1977
# This was written to movie_data.csv: Wolfen 1981
# This was written to movie_data.csv: Hooper 1978
# This was written to movie_data.csv: Love at First Bite 1979
# This was written to movie_data.csv: The Great Santini 1979
# This was written to movie_data.csv: Meteor 1979
# This was written to movie_data.csv: The Osterman Weekend 1983
# This was written to movie_data.csv: Cheech & Chong's: The Corsican Brothers 1984
# This was written to movie_data.csv: Iceman 1984
# This was written to movie_data.csv: Teachers 1984
# This was written to movie_data.csv: Code of Silence 1985
# This was written to movie_data.csv: Heaven Help Us 1985
# This was written to movie_data.csv: Black Moon Rising 1986
# This was written to movie_data.csv: Club Paradise 1986
# This was written to movie_data.csv: My Little Pony: The Movie 1986
# This was written to movie_data.csv: Tough Guys 1986
# This was written to movie_data.csv: Trick or Treat 1986
# This was written to movie_data.csv: Death Wish 4: The Crackdown 1987
# This was written to movie_data.csv: Extreme Prejudice 1987
# This was written to movie_data.csv: Made in Heaven 1987
# This was written to movie_data.csv: Nuts 1987
# This was written to movie_data.csv: The Principal 1987
# This was written to movie_data.csv: Arthur 2: On the Rocks 1988
# This was written to movie_data.csv: Fresh Horses 1988
# This was written to movie_data.csv: Dad 1989
# This was written to movie_data.csv: Moving 1988
# This was written to movie_data.csv: Punchline 1988
# This was written to movie_data.csv: Prancer 1989
# This was written to movie_data.csv: Stealing Home 1988
# This was written to movie_data.csv: Sunset 1988
# This was written to movie_data.csv: Jetsons: The Movie 1990
# This was written to movie_data.csv: The Perfect Weapon 1991
# This was written to movie_data.csv: Pure Luck 1991
# This was written to movie_data.csv: Shout 1991
# This was written to movie_data.csv: Strictly Business 1991
# This was written to movie_data.csv: Sarafina! 1992
# This was written to movie_data.csv: Best of the Best II 1993
# This was written to movie_data.csv: The Temp 1993
# This was written to movie_data.csv: Getting Even with Dad 1994
# This was written to movie_data.csv: Lassie 1994
# This was written to movie_data.csv: Lightning Jack 1994
# This was written to movie_data.csv: Sugar Hill 1993
# This was written to movie_data.csv: Wagons East 1994
# This was written to movie_data.csv: White Man's Burden 1995
# This was written to movie_data.csv: Big Bully 1996
# This was written to movie_data.csv: Celtic Pride 1996
# This was written to movie_data.csv: Heaven's Prisoners 1996
# This was written to movie_data.csv: If Lucy Fell 1996
# This was written to movie_data.csv: Lawnmower Man 2: Beyond Cyberspace 1995
# This was written to movie_data.csv: The Spitfire Grill 1996
# This was written to movie_data.csv: 8 Heads in a Duffel Bag 1997
# This was written to movie_data.csv: The Beautician and the Beast 1997
# This was written to movie_data.csv: Meet Wally Sparks 1997
# This was written to movie_data.csv: A Thousand Acres 1997
# This was written to movie_data.csv: Zeus and Roxanne 1997
# This was written to movie_data.csv: The Odd Couple II 1998
# This was written to movie_data.csv: Palmetto 1998
# This was written to movie_data.csv: Chill Factor 1999
# This was written to movie_data.csv: Light It Up 1999
# This was written to movie_data.csv: The Muse 1999
# This was written to movie_data.csv: The Crew 2000
# This was written to movie_data.csv: King's Ransom 2005
# This was written to movie_data.csv: The Honeymooners 2005
# This was written to movie_data.csv: Feel the Noise 2007
# This was written to movie_data.csv: Hannah Montana and Miley Cyrus: Best of Both Worlds Concert 2008
# This was written to movie_data.csv: Cecil B. Demented 2000
# This was written to movie_data.csv: What Becomes of the Broken Hearted? 1999
# This was written to movie_data.csv: Stranded 2001
# This was written to movie_data.csv: The Battle of Shaker Heights 2003
# This was written to movie_data.csv: Spiders 2000
# This was written to movie_data.csv: Malevolence 2003
# This was written to movie_data.csv: The Big Kahuna 1999
# This was written to movie_data.csv: American Women 2000
# This was written to movie_data.csv: Unconditional Love 2002
# This was written to movie_data.csv: Harvard Man 2001
# This was written to movie_data.csv: Octane 2003
# This was written to movie_data.csv: The Bank 2001
# This was written to movie_data.csv: The Foreigner 2003
# This was written to movie_data.csv: Resurrection 1999
# This was written to movie_data.csv: Haggard 2003
# This was written to movie_data.csv: The Trip 2002
# This was written to movie_data.csv: A Shot at Glory 2000
# This was written to movie_data.csv: The Winslow Boy 1999
# This was written to movie_data.csv: Fortress 2: Re-Entry 2000
# This was written to movie_data.csv: State Property 2002
# This was written to movie_data.csv: The First $20 Million Is Always the Hardest 2002
# This was written to movie_data.csv: Love's Labour's Lost 2000
# This was written to movie_data.csv: Harrison's Flowers 2000
# This was written to movie_data.csv: The Body 2001
# This was written to movie_data.csv: Mambo Italiano 2003
# This was written to movie_data.csv: The Dancer Upstairs 2002
# This was written to movie_data.csv: Daddy and Them 2001
# This was written to movie_data.csv: Thick as Thieves 1999
# This was written to movie_data.csv: Scotland, Pa. 2001
# This was written to movie_data.csv: Coming Soon 1999
# This was written to movie_data.csv: Tumbleweeds 1999
# This was written to movie_data.csv: The Hebrew Hammer 2003
# This was written to movie_data.csv: Bloodsport 2 1996
# This was written to movie_data.csv: Jeffrey 1995
# This was written to movie_data.csv: Face 1997
# This was written to movie_data.csv: Besieged 1998
# This was written to movie_data.csv: Mother's Boys 1993
# This was written to movie_data.csv: Digging to China 1997
# This was written to movie_data.csv: The Real Blonde 1997
# This was written to movie_data.csv: Henry Fool 1997
# This was written to movie_data.csv: Head On 1998
# This was written to movie_data.csv: Citizen Ruth 1996
# This was written to movie_data.csv: Dog Park 1998
# This was written to movie_data.csv: Mother Night 1996
# This was written to movie_data.csv: Edge of Seventeen 1998
# This was written to movie_data.csv: The Fantastic Four 1994
# This was written to movie_data.csv: Oscar and Lucinda 1997
# This was written to movie_data.csv: American Buffalo 1996
# This was written to movie_data.csv: The Stöned Age 1994
# This was written to movie_data.csv: Puddle Cruiser 1996
# This was written to movie_data.csv: The Addiction 1995
# This was written to movie_data.csv: Phoenix 1998
# This was written to movie_data.csv: Death Machine 1994
# This was written to movie_data.csv: Wild Side 1995
# This was written to movie_data.csv: Ulysses' Gaze 1995
# This was written to movie_data.csv: Breaking Up 1997
# This was written to movie_data.csv: Critters 4 1992
# This was written to movie_data.csv: Homicide 1991
# This was written to movie_data.csv: Fire on the Amazon 1993
# This was written to movie_data.csv: Brain Dead 1990
# This was written to movie_data.csv: Intruder 1989
# This was written to movie_data.csv: Moon 44 1990
# This was written to movie_data.csv: Jacknife 1989
# This was written to movie_data.csv: Trust 1990
# This was written to movie_data.csv: Longtime Companion 1989
# This was written to movie_data.csv: Nemesis 1992
# This was written to movie_data.csv: The Reflecting Skin 1990
# This was written to movie_data.csv: The Comfort of Strangers 1990
# This was written to movie_data.csv: Music Box 1989
# This was written to movie_data.csv: Side Out 1990
# This was written to movie_data.csv: The Hitman 1991
# This was written to movie_data.csv: Wedlock 1991
# This was written to movie_data.csv: A Shock to the System 1990
# This was written to movie_data.csv: Waxwork II: Lost in Time 1992
# This was written to movie_data.csv: Prospero's Books 1991
# This was written to movie_data.csv: She's Gotta Have It 1986
# This was written to movie_data.csv: Rita, Sue and Bob Too 1987
# This was written to movie_data.csv: Ghoulies 1984
# This was written to movie_data.csv: Watchers 1988
# This was written to movie_data.csv: No Man's Land 1987
# This was written to movie_data.csv: Chopping Mall 1986
# This was written to movie_data.csv: Slugs 1988
# This was written to movie_data.csv: White Water Summer 1987
# This was written to movie_data.csv: Miracle Mile 1988
# This was written to movie_data.csv: Class of Nuke 'Em High 1986
# This was written to movie_data.csv: The Boys Next Door 1985
# This was written to movie_data.csv: American Ninja 2: The Confrontation 1987
# This was written to movie_data.csv: Demons 2 1986
# This was written to movie_data.csv: Daffy Duck's Quackbusters 1988
# This was written to movie_data.csv: Razorback 1984
# This was written to movie_data.csv: The Hit 1984
# This was written to movie_data.csv: Steel Dawn 1987
# This was written to movie_data.csv: The Chocolate War 1988
# This was written to movie_data.csv: Siesta 1987
# This was written to movie_data.csv: The Glass Menagerie 1987
# This was written to movie_data.csv: Knightriders 1981
# This was written to movie_data.csv: Chained Heat 1983
# This was written to movie_data.csv: Resurrection 1980
# This was written to movie_data.csv: The Stunt Man 1980
# This was written to movie_data.csv: Mephisto 1981
# This was written to movie_data.csv: Deathstalker 1983
# This was written to movie_data.csv: The Octagon 1980
# This was written to movie_data.csv: Savannah Smiles 1982
# This was written to movie_data.csv: Barbarosa 1982
# This was written to movie_data.csv: Tourist Trap 1979
# This was written to movie_data.csv: Prince of the City 1981
# This was written to movie_data.csv: The Ninth Configuration 1980
# This was written to movie_data.csv: Super Fuzz 1980
# This was written to movie_data.csv: The Plague Dogs 1982
# This was written to movie_data.csv: Eaten Alive 1976
# This was written to movie_data.csv: Cannonball! 1976
# This was written to movie_data.csv: Ode to Billy Joe 1976
# This was written to movie_data.csv: Boss Nigger 1974
# This was written to movie_data.csv: Images 1972
# This was written to movie_data.csv: The Great Waldo Pepper 1975
# This was written to movie_data.csv: The Yakuza 1974
# This was written to movie_data.csv: Mr. Majestyk 1974
# This was written to movie_data.csv: Let Sleeping Corpses Lie 1974
# This was written to movie_data.csv: It's Alive 1974
# This was written to movie_data.csv: Phase IV 1974
# This was written to movie_data.csv: Stardust 1974
# This was written to movie_data.csv: The Front 1976
# This was written to movie_data.csv: Lipstick 1976
# This was written to movie_data.csv: The Slipper and the Rose: The Story of Cinderella 1976
# This was written to movie_data.csv: The Other Side of Midnight 1977
# This was written to movie_data.csv: The Island of Dr. Moreau 1977
# This was written to movie_data.csv: Rollercoaster 1977
# This was written to movie_data.csv: An Unmarried Woman 1978
# This was written to movie_data.csv: Blue Collar 1978
# This was written to movie_data.csv: The Boys in Company C 1978
# This was written to movie_data.csv: The Big Sleep 1978
# This was written to movie_data.csv: Continental Divide 1981
# This was written to movie_data.csv: The Border 1982
# This was written to movie_data.csv: The Innocent 1976
# This was written to movie_data.csv: The Last Wave 1977
# This was written to movie_data.csv: Corvette Summer 1978
# This was written to movie_data.csv: The Swarm 1978
# This was written to movie_data.csv: Escape to Athena 1979
# This was written to movie_data.csv: Hanover Street 1979
# This was written to movie_data.csv: Yanks 1979
# This was written to movie_data.csv: The Apple Dumpling Gang Rides Again 1979
# This was written to movie_data.csv: Silent Rage 1982
# This was written to movie_data.csv: Young Doctors in Love 1982
# This was written to movie_data.csv: Curse of the Pink Panther 1983
# This was written to movie_data.csv: High Road to China 1983
# This was written to movie_data.csv: The Survivors 1983
# This was written to movie_data.csv: Two of a Kind 1983
# This was written to movie_data.csv: Moscow on the Hudson 1984
# This was written to movie_data.csv: Reckless 1984
# This was written to movie_data.csv: The Flamingo Kid 1984
# This was written to movie_data.csv: The River 1984
# This was written to movie_data.csv: Missing in Action 2: The Beginning 1985
# This was written to movie_data.csv: Moving Violations 1985
# This was written to movie_data.csv: 52 Pick-Up 1986
# This was written to movie_data.csv: Brighton Beach Memoirs 1986
# This was written to movie_data.csv: King Kong Lives 1986
# This was written to movie_data.csv: The Morning After 1986
# This was written to movie_data.csv: Light of Day 1987
# This was written to movie_data.csv: Hot Pursuit 1987
# This was written to movie_data.csv: Like Father Like Son 1987
# This was written to movie_data.csv: Betrayed 1988
# This was written to movie_data.csv: Braddock: Missing in Action III 1988
# This was written to movie_data.csv: Return to Snowy River 1988
# This was written to movie_data.csv: Vibes 1988
# This was written to movie_data.csv: Flashback 1990
# This was written to movie_data.csv: True Believer 1989
# This was written to movie_data.csv: Narrow Margin 1990
# This was written to movie_data.csv: Nuns on the Run 1990
# This was written to movie_data.csv: Welcome Home, Roxy Carmichael 1990
# This was written to movie_data.csv: Class Action 1991
# This was written to movie_data.csv: A Kiss Before Dying 1991
# This was written to movie_data.csv: Once Around 1991
# This was written to movie_data.csv: The Butcher's Wife 1991
# This was written to movie_data.csv: Delirious 1991
# This was written to movie_data.csv: Life Stinks 1991
# This was written to movie_data.csv: Dr. Giggles 1992
# This was written to movie_data.csv: Mom and Dad Save the World 1992
# This was written to movie_data.csv: Prelude to a Kiss 1992
# This was written to movie_data.csv: A Stranger Among Us 1992
# This was written to movie_data.csv: Amos & Andrew 1993
# This was written to movie_data.csv: Born Yesterday 1993
# This was written to movie_data.csv: Guilty as Sin 1993
# This was written to movie_data.csv: Son of the Pink Panther 1993
# This was written to movie_data.csv: Angie 1994
# This was written to movie_data.csv: Speechless 1994
# This was written to movie_data.csv: The Hunted 1995
# This was written to movie_data.csv: The Mangler 1995
# This was written to movie_data.csv: Bushwhacked 1995
# This was written to movie_data.csv: Destiny Turns on the Radio 1995
# This was written to movie_data.csv: Fled 1996
# This was written to movie_data.csv: Last Dance 1996
# This was written to movie_data.csv: The Pallbearer 1996
# This was written to movie_data.csv: The Stupids 1996
# This was written to movie_data.csv: The Associate 1996
# This was written to movie_data.csv: Larger Than Life 1996
# This was written to movie_data.csv: Buddy 1997
# This was written to movie_data.csv: Out to Sea 1997
# This was written to movie_data.csv: Shadow Conspiracy 1997
# This was written to movie_data.csv: Kissing a Fool 1998
# This was written to movie_data.csv: My Giant 1998
# This was written to movie_data.csv: Air Bud: Golden Receiver 1998
# This was written to movie_data.csv: Gloria 1999
# This was written to movie_data.csv: Goodbye Lover 1998
# This was written to movie_data.csv: The King and I 1999
# This was written to movie_data.csv: Lost & Found 1999
# This was written to movie_data.csv: Held Up 1999
# This was written to movie_data.csv: The in Crowd 2000
# This was written to movie_data.csv: Screwed 2000
# This was written to movie_data.csv: Town & Country 2001
# This was written to movie_data.csv: The Crocodile Hunter: Collision Course 2002
# This was written to movie_data.csv: The Gospel 2005
# This was written to movie_data.csv: Undiscovered 2005
# This was written to movie_data.csv: The Ten Commandments 2007
# This was written to movie_data.csv: Jonas Brothers: The 3D Concert Experience 2009
# This was written to movie_data.csv: Count Dracula 1970
# This was written to movie_data.csv: Pauly Shore Is Dead 2003
# This was written to movie_data.csv: Miss Julie 1999
# This was written to movie_data.csv: Sidewalks of New York 2001
# This was written to movie_data.csv: Little Secrets 2001
# This was written to movie_data.csv: Deeply 2000
# This was written to movie_data.csv: Kaena: The Prophecy 2003
# This was written to movie_data.csv: Good Advice 2001
# This was written to movie_data.csv: On the Edge 2001
# This was written to movie_data.csv: Imagining Argentina 2003
# This was written to movie_data.csv: The Parole Officer 2001
# This was written to movie_data.csv: Ararat 2002
# This was written to movie_data.csv: Picking Up the Pieces 2000
# This was written to movie_data.csv: Alexandra's Project 2003
# This was written to movie_data.csv: Skipped Parts 2000
# This was written to movie_data.csv: Amy's Orgasm 2001
# This was written to movie_data.csv: Anne B. Real 2003
# This was written to movie_data.csv: Pure 2002
# This was written to movie_data.csv: Mad About Mambo 2000
# This was written to movie_data.csv: The 4th Floor 1999
# This was written to movie_data.csv: The Minus Man 1999
# This was written to movie_data.csv: Simon Sez 1999
# This was written to movie_data.csv: MVP: Most Valuable Primate 2000
# This was written to movie_data.csv: An American Rhapsody 2001
# This was written to movie_data.csv: Going Greek 2001
# This was written to movie_data.csv: Last Orders 2001
# This was written to movie_data.csv: Happy, Texas 1999
# This was written to movie_data.csv: The Omega Code 1999
# This was written to movie_data.csv: The Statement 2003
# This was written to movie_data.csv: Chuck & Buck 2000
# This was written to movie_data.csv: Liberty Stands Still 2002
# This was written to movie_data.csv: Series 7: The Contenders 2001
# This was written to movie_data.csv: Jesus Christ Vampire Hunter 2001
# This was written to movie_data.csv: A Room for Romeo Brass 1999
# This was written to movie_data.csv: Citizen Toxie: The Toxic Avenger IV 2000
# This was written to movie_data.csv: Grand Theft Parsons 2003
# This was written to movie_data.csv: The Tony Blair Witch Project 2000
# This was written to movie_data.csv: George Washington 2000
# This was written to movie_data.csv: Rolling Kansas 2003
# This was written to movie_data.csv: My First Mister 2001
# This was written to movie_data.csv: Hugo Pool 1997
# This was written to movie_data.csv: The Hi-Lo Country 1998
# This was written to movie_data.csv: The Pit and the Pendulum 1991
# This was written to movie_data.csv: Grand Tour: Disaster in Time 1991
# This was written to movie_data.csv: Ethan Frome 1992
# This was written to movie_data.csv: True Colors 1991
# This was written to movie_data.csv: Ticks 1993
# This was written to movie_data.csv: The Tall Guy 1989
# This was written to movie_data.csv: Cannibal Women in the Avocado Jungle of Death 1989
# This was written to movie_data.csv: Prayer of the Rollerboys 1990
# This was written to movie_data.csv: Highway to Hell 1991
# This was written to movie_data.csv: Parents 1989
# This was written to movie_data.csv: Trauma 1993
# This was written to movie_data.csv: At Play in the Fields of the Lord 1991
# This was written to movie_data.csv: American Ninja 5 1993
# This was written to movie_data.csv: American Ninja 4: The Annihilation 1990
# This was written to movie_data.csv: Prison 1987
# This was written to movie_data.csv: A Prayer for the Dying 1987
# This was written to movie_data.csv: White Mischief 1987
# This was written to movie_data.csv: Lost in America 1985
# This was written to movie_data.csv: A Zed & Two Noughts 1985
# This was written to movie_data.csv: Surf Nazis Must Die 1987
# This was written to movie_data.csv: My Best Friend Is a Vampire 1987
# This was written to movie_data.csv: The Barbarians 1987
# This was written to movie_data.csv: Anguish 1987
# This was written to movie_data.csv: The Element of Crime 1984
# This was written to movie_data.csv: Torch Song Trilogy 1988
# This was written to movie_data.csv: Combat Shock 1984
# This was written to movie_data.csv: September 1987
# This was written to movie_data.csv: Querelle 1982
# This was written to movie_data.csv: Tempest 1982
# This was written to movie_data.csv: The Chosen 1981
# This was written to movie_data.csv: The Killer Elite 1975
# This was written to movie_data.csv: Sleeping Dogs 1977
# This was written to movie_data.csv: Brannigan 1975
# This was written to movie_data.csv: The Toolbox Murders 1978
# This was written to movie_data.csv: The Manitou 1978
# This was written to movie_data.csv: Carry on Abroad 1972
# This was written to movie_data.csv: The Outfit 1973
# This was written to movie_data.csv: Emperor of the North 1973
# This was written to movie_data.csv: Lolly-Madonna XXX 1973
# This was written to movie_data.csv: Dracula A.D. 1972 1972
# This was written to movie_data.csv: The Heartbreak Kid 1972
# This was written to movie_data.csv: The Drowning Pool 1975
# This was written to movie_data.csv: Race with the Devil 1975
# This was written to movie_data.csv: California Split 1974
# This was written to movie_data.csv: McQ 1974
# This was written to movie_data.csv: A Touch of Class 1973
# This was written to movie_data.csv: Cinderella Liberty 1973
# This was written to movie_data.csv: Siddhartha 1972
# This was written to movie_data.csv: What? 1972
# This was written to movie_data.csv: The Bitter Tears of Petra von Kant 1972
# This was written to movie_data.csv: Face to Face 1976
# This was written to movie_data.csv: The Cassandra Crossing 1976
# This was written to movie_data.csv: Grizzly 1976
# This was written to movie_data.csv: Mother, Jugs & Speed 1976
# This was written to movie_data.csv: To the Devil a Daughter 1976
# This was written to movie_data.csv: Voyage of the Damned 1976
# This was written to movie_data.csv: Two-Minute Warning 1976
# This was written to movie_data.csv: Heroes 1977
# This was written to movie_data.csv: Opening Night 1977
# This was written to movie_data.csv: Candleshoe 1977
# This was written to movie_data.csv: Godzilla vs. Mechagodzilla 1974
# This was written to movie_data.csv: The Valley (Obscured by Clouds) 1972
# This was written to movie_data.csv: Bustin' Loose 1981
# This was written to movie_data.csv: The Four Seasons 1981
# This was written to movie_data.csv: A Wedding 1978
# This was written to movie_data.csv: The Bad News Bears Go to Japan 1978
# This was written to movie_data.csv: A Force of One 1979
# This was written to movie_data.csv: H.O.T.S. 1979
# This was written to movie_data.csv: The Main Event 1979
# This was written to movie_data.csv: North Dallas Forty 1979
# This was written to movie_data.csv: Prophecy 1979
# This was written to movie_data.csv: The Man Who Loved Women 1983
# This was written to movie_data.csv: The Star Chamber 1983
# This was written to movie_data.csv: Best Defense 1984
# This was written to movie_data.csv: Irreconcilable Differences 1984
# This was written to movie_data.csv: Swing Shift 1984
# This was written to movie_data.csv: Unfaithfully Yours 1984
# This was written to movie_data.csv: Mrs. Soffel 1984
# This was written to movie_data.csv: Agnes of God 1985
# This was written to movie_data.csv: Gymkata 1985
# This was written to movie_data.csv: American Anthem 1986
# This was written to movie_data.csv: Under the Cherry Moon 1986
# This was written to movie_data.csv: Witchboard 1986
# This was written to movie_data.csv: Wisdom 1986
# This was written to movie_data.csv: The Believers 1987
# This was written to movie_data.csv: Date with an Angel 1987
# This was written to movie_data.csv: Gardens of Stone 1987
# This was written to movie_data.csv: Tin Men 1987
# This was written to movie_data.csv: Gross Anatomy 1989
# This was written to movie_data.csv: Iron Eagle II 1988
# This was written to movie_data.csv: In Country 1989
# This was written to movie_data.csv: Let It Ride 1989
# This was written to movie_data.csv: Moon Over Parador 1988
# This was written to movie_data.csv: A Night in the Life of Jimmy Reardon 1988
# This was written to movie_data.csv: Off Limits 1988
# This was written to movie_data.csv: Salsa 1988
# This was written to movie_data.csv: Almost an Angel 1990
# This was written to movie_data.csv: Betsy's Wedding 1990
# This was written to movie_data.csv: Her Alibi 1989
# This was written to movie_data.csv: The Forbidden Dance 1990
# This was written to movie_data.csv: Graffiti Bridge 1990
# This was written to movie_data.csv: Men Don't Leave 1990
# This was written to movie_data.csv: Opportunity Knocks 1990
# This was written to movie_data.csv: Q&A 1990
# This was written to movie_data.csv: Spaced Invaders 1990
# This was written to movie_data.csv: The Marrying Man 1991
# This was written to movie_data.csv: Another You 1991
# This was written to movie_data.csv: Body Parts 1991
# This was written to movie_data.csv: For the Boys 1991
# This was written to movie_data.csv: The Super 1991
# This was written to movie_data.csv: Out on a Limb 1992
# This was written to movie_data.csv: White Sands 1992
# This was written to movie_data.csv: Wind 1992
# This was written to movie_data.csv: Ghost in the Machine 1993
# This was written to movie_data.csv: The Real McCoy 1993
# This was written to movie_data.csv: Chasers 1994
# This was written to movie_data.csv: The Princess and the Goblin 1991
# This was written to movie_data.csv: White Fang 2: Myth of the White Wolf 1994
# This was written to movie_data.csv: Beyond Rangoon 1995
# This was written to movie_data.csv: Gordy 1994
# This was written to movie_data.csv: Jury Duty 1995
# This was written to movie_data.csv: Three Wishes 1995
# This was written to movie_data.csv: Night Falls on Manhattan 1996
# This was written to movie_data.csv: Meet the Deedles 1998
# This was written to movie_data.csv: 3 Strikes 2000
# This was written to movie_data.csv: Extreme Ops 2002
# This was written to movie_data.csv: Hey Arnold! The Movie 2002
# This was written to movie_data.csv: Friends & Lovers 1999
# This was written to movie_data.csv: Gettin' Square 2003
# This was written to movie_data.csv: Borstal Boy 2000
# This was written to movie_data.csv: Alien Hunter 2003
# This was written to movie_data.csv: Fear of the Dark 2003
# This was written to movie_data.csv: Japanese Story 2003
# This was written to movie_data.csv: Tart 2001
# This was written to movie_data.csv: Molly 1999
# This was written to movie_data.csv: Vampires: Los Muertos 2002
# This was written to movie_data.csv: 8 ½ Women 1999
# This was written to movie_data.csv: Song for a Raggy Boy 2003
# This was written to movie_data.csv: Sunshine State 2002
# This was written to movie_data.csv: Stolen Summer 2002
# This was written to movie_data.csv: Anita & Me 2002
# This was written to movie_data.csv: The American Astronaut 2001
# This was written to movie_data.csv: The Suburbans 1999
# This was written to movie_data.csv: Route 666 2001
# This was written to movie_data.csv: Stark Raving Mad 2002
# This was written to movie_data.csv: The Confession 1999
# This was written to movie_data.csv: Oxygen 1999
# This was written to movie_data.csv: The Bone Snatcher 2003
# This was written to movie_data.csv: Megiddo: The Omega Code 2 2001
# This was written to movie_data.csv: Hard Cash 2002
# This was written to movie_data.csv: Detention 2003
# This was written to movie_data.csv: Nothing 2003
# This was written to movie_data.csv: Guinevere 1999
# This was written to movie_data.csv: Undertaking Betty 2002
# This was written to movie_data.csv: Girl Fever 2002
# This was written to movie_data.csv: Limbo 1999
# This was written to movie_data.csv: Hotel 2001
# This was written to movie_data.csv: .com for Murder 2002
# This was written to movie_data.csv: Cheaters 2002
# This was written to movie_data.csv: The Convent 2000
# This was written to movie_data.csv: A Map of the World 1999
# This was written to movie_data.csv: The Wog Boy 2000
# This was written to movie_data.csv: Twister 1989
# This was written to movie_data.csv: Motorama 1991
# This was written to movie_data.csv: Naked in New York 1993
# This was written to movie_data.csv: The Toxic Avenger Part II 1989
# This was written to movie_data.csv: The Efficiency Expert 1991
# This was written to movie_data.csv: Dragon Ball Z: The Tree of Might 1990
# This was written to movie_data.csv: Totally F***ed Up 1993
# This was written to movie_data.csv: The Waterdance 1992
# This was written to movie_data.csv: Clean, Shaven 1993
# This was written to movie_data.csv: The Trial 1993
# This was written to movie_data.csv: Live Wire 1992
# This was written to movie_data.csv: The Return of the Musketeers 1989
# This was written to movie_data.csv: Evil Toons 1992
# This was written to movie_data.csv: Poison 1991
# This was written to movie_data.csv: High Strung 1992
# This was written to movie_data.csv: The Siege of Firebase Gloria 1988
# This was written to movie_data.csv: Slipstream 1989
# This was written to movie_data.csv: Philadelphia Experiment II 1993
# This was written to movie_data.csv: Maria's Lovers 1984
# This was written to movie_data.csv: Morons from Outer Space 1985
# This was written to movie_data.csv: The Sicilian 1987
# This was written to movie_data.csv: Slaughter High 1986
# This was written to movie_data.csv: StageFright 1987
# This was written to movie_data.csv: Savage Streets 1984
# This was written to movie_data.csv: And God Created Woman 1988
# This was written to movie_data.csv: Paperhouse 1988
# This was written to movie_data.csv: Hollywood Shuffle 1987
# This was written to movie_data.csv: True Stories 1986
# This was written to movie_data.csv: Return to Horror High 1987
# This was written to movie_data.csv: Rocket Gibraltar 1988
# This was written to movie_data.csv: Straight to Hell 1987
# This was written to movie_data.csv: Ninja III: The Domination 1984
# This was written to movie_data.csv: Mala Noche 1986
# This was written to movie_data.csv: Swallows and Amazons 1974
# This was written to movie_data.csv: Island of Death 1976
# This was written to movie_data.csv: Rockers 1978
# This was written to movie_data.csv: Bug 1975
# This was written to movie_data.csv: Ilsa, the Wicked Warden 1977
# This was written to movie_data.csv: Who Can Kill a Child? 1976
# This was written to movie_data.csv: The Legacy 1978
# This was written to movie_data.csv: The Devil's Rain 1975
# This was written to movie_data.csv: The White Buffalo 1977
# This was written to movie_data.csv: Uptown Saturday Night 1974
# This was written to movie_data.csv: Blood Sucking Freaks 1976
# This was written to movie_data.csv: The Baby 1973
# This was written to movie_data.csv: Lady Snowblood 1973
# This was written to movie_data.csv: Hit! 1973
# This was written to movie_data.csv: Theater of Blood 1973
# This was written to movie_data.csv: The Satanic Rites of Dracula 1973
# This was written to movie_data.csv: Save the Tiger 1973
# This was written to movie_data.csv: Lost Horizon 1973
# This was written to movie_data.csv: The Fortune 1975
# This was written to movie_data.csv: One of Our Dinosaurs Is Missing 1975
# This was written to movie_data.csv: Harry and Tonto 1974
# This was written to movie_data.csv: Big Bad Mama 1974
# This was written to movie_data.csv: The Gambler 1974
# This was written to movie_data.csv: The Groove Tube 1974
# This was written to movie_data.csv: The MacKintosh Man 1973
# This was written to movie_data.csv: The Grand Duel 1972
# This was written to movie_data.csv: The Call of the Wild 1972
# This was written to movie_data.csv: Breakheart Pass 1975
# This was written to movie_data.csv: Let's Do It Again 1975
# This was written to movie_data.csv: The Sunshine Boys 1975
# This was written to movie_data.csv: Gus 1976
# This was written to movie_data.csv: Next Stop, Greenwich Village 1976
# This was written to movie_data.csv: The Sailor Who Fell from Grace with the Sea 1976
# This was written to movie_data.csv: Keoma 1976
# This was written to movie_data.csv: Fun with Dick and Jane 1977
# This was written to movie_data.csv: Gray Lady Down 1978
# This was written to movie_data.csv: Honeysuckle Rose 1980
# This was written to movie_data.csv: Oh, God! Book II 1980
# This was written to movie_data.csv: ABBA: The Movie 1977
# This was written to movie_data.csv: Go Tell the Spartans 1978
# This was written to movie_data.csv: Hot Lead and Cold Feet 1978
# This was written to movie_data.csv: The Silent Partner 1978
# This was written to movie_data.csv: Starting Over 1979
# This was written to movie_data.csv: Murder by Decree 1979
# This was written to movie_data.csv: Wise Blood 1979
# This was written to movie_data.csv: Woyzeck 1979
# This was written to movie_data.csv: The Bugs Bunny/Road-Runner Movie 1979
# This was written to movie_data.csv: Agatha 1979
# This was written to movie_data.csv: Best Friends 1982
# This was written to movie_data.csv: Class Reunion 1982
# This was written to movie_data.csv: Visiting Hours 1982
# This was written to movie_data.csv: The Lords of Discipline 1983
# This was written to movie_data.csv: The Sting II 1983
# This was written to movie_data.csv: Stroker Ace 1983
# This was written to movie_data.csv: Grandview, U.S.A. 1984
# This was written to movie_data.csv: Hard to Hold 1984
# This was written to movie_data.csv: The Lonely Guy 1984
# This was written to movie_data.csv: Protocol 1984
# This was written to movie_data.csv: Baby: Secret of the Lost Legend 1985
# This was written to movie_data.csv: Target 1985
# This was written to movie_data.csv: Band of the Hand 1986
# This was written to movie_data.csv: Eliminators 1986
# This was written to movie_data.csv: Critical Condition 1987
# This was written to movie_data.csv: Wanted: Dead or Alive 1986
# This was written to movie_data.csv: The Big Town 1987
# This was written to movie_data.csv: Fatal Beauty 1987
# This was written to movie_data.csv: Leonard Part 6 1987
# This was written to movie_data.csv: Nadine 1987
# This was written to movie_data.csv: The Couch Trip 1988
# This was written to movie_data.csv: The Good Mother 1988
# This was written to movie_data.csv: Hero and the Terror 1988
# This was written to movie_data.csv: Memories of Me 1988
# This was written to movie_data.csv: The Phantom of the Opera 1989
# This was written to movie_data.csv: Cousins 1989
# This was written to movie_data.csv: The First Power 1990
# This was written to movie_data.csv: The January Man 1989
# This was written to movie_data.csv: Heart Condition 1990
# This was written to movie_data.csv: Loose Cannons 1990
# This was written to movie_data.csv: Madhouse 1990
# This was written to movie_data.csv: Shipwrecked 1990
# This was written to movie_data.csv: Paradise 1991
# This was written to movie_data.csv: V.I. Warshawski 1991
# This was written to movie_data.csv: Mr. Saturday Night 1992
# This was written to movie_data.csv: Man Trouble 1992
# This was written to movie_data.csv: Night and the City 1992
# This was written to movie_data.csv: Once Upon a Crime... 1992
# This was written to movie_data.csv: Jack the Bear 1993
# This was written to movie_data.csv: The Opposite Sex and How to Live with Them 1992
# This was written to movie_data.csv: Splitting Heirs 1993
# This was written to movie_data.csv: Josh and S.A.M. 1993
# This was written to movie_data.csv: Mr. Wonderful 1993
# This was written to movie_data.csv: The Nutcracker 1993
# This was written to movie_data.csv: Radioland Murders 1994
# This was written to movie_data.csv: Silent Fall 1994
# This was written to movie_data.csv: Far from Home: The Adventures of Yellow Dog 1995
# This was written to movie_data.csv: The Perez Family 1995
# This was written to movie_data.csv: Bogus 1996
# This was written to movie_data.csv: Solo 1996
# This was written to movie_data.csv: Mother 1996
# This was written to movie_data.csv: Masterminds 1997
# This was written to movie_data.csv: Caught Up 1998
# This was written to movie_data.csv: Tarzan and the Lost City 1998
# This was written to movie_data.csv: Ringmaster 1998
# This was written to movie_data.csv: Where the Money Is 2000
# This was written to movie_data.csv: Whipped 2000
# This was written to movie_data.csv: Kingdom Come 2001
# This was written to movie_data.csv: Don't Torture a Duckling 1972
# This was written to movie_data.csv: Gold Diggers 2003
# This was written to movie_data.csv: Prey for Rock & Roll 2003
# This was written to movie_data.csv: Survival Island 2002
# This was written to movie_data.csv: Bookies 2003
# This was written to movie_data.csv: He Died with a Felafel in His Hand 2001
# This was written to movie_data.csv: The Last Horror Movie 2003
# This was written to movie_data.csv: I Love Your Work 2003
# This was written to movie_data.csv: Blue Car 2002
# This was written to movie_data.csv: It Had to Be You 2000
# This was written to movie_data.csv: Up at the Villa 2000
# This was written to movie_data.csv: Crime + Punishment in Suburbia 2000
# This was written to movie_data.csv: Long Time Dead 2002
# This was written to movie_data.csv: Sweetie 1989
# This was written to movie_data.csv: Passion Fish 1992
# This was written to movie_data.csv: Kill Me Again 1989
# This was written to movie_data.csv: Mindwalk 1990
# This was written to movie_data.csv: Lucky Luke 1991
# This was written to movie_data.csv: Riff-Raff 1991
# This was written to movie_data.csv: Sundown: The Vampire in Retreat 1989
# This was written to movie_data.csv: Dangerous Game 1993
# This was written to movie_data.csv: Undefeatable 1993
# This was written to movie_data.csv: Light Sleeper 1992
# This was written to movie_data.csv: American Heart 1992
# This was written to movie_data.csv: Rover Dangerfield 1991
# This was written to movie_data.csv: Mistress 1992
# This was written to movie_data.csv: Company Business 1991
# This was written to movie_data.csv: The Dark Side of the Moon 1990
# This was written to movie_data.csv: Brain Donors 1992
# This was written to movie_data.csv: The Return of Swamp Thing 1989
# This was written to movie_data.csv: Penn & Teller Get Killed 1989
# This was written to movie_data.csv: Hidden Agenda 1990
# This was written to movie_data.csv: Gas Food Lodging 1992
# This was written to movie_data.csv: Map of the Human Heart 1992
# This was written to movie_data.csv: The Eight Immortals Restaurant: The Untold Story 1993
# This was written to movie_data.csv: After Dark, My Sweet 1990
# This was written to movie_data.csv: American Ninja 3: Blood Hunt 1989
# This was written to movie_data.csv: Fear of a Black Hat 1993
# This was written to movie_data.csv: Big Girls Don't Cry... They Get Even 1991
# This was written to movie_data.csv: Where the Heart Is 1990
# This was written to movie_data.csv: 976-EVIL 1988
# This was written to movie_data.csv: Creature 1985
# This was written to movie_data.csv: Cheerleader Camp 1988
# This was written to movie_data.csv: Dominick and Eugene 1988
# This was written to movie_data.csv: High Hopes 1988
# This was written to movie_data.csv: Under the Volcano 1984
# This was written to movie_data.csv: A Handful of Dust 1988
# This was written to movie_data.csv: Sword of the Valiant 1984
# This was written to movie_data.csv: The Night Before 1988
# This was written to movie_data.csv: Real Men 1987
# This was written to movie_data.csv: Space Mutiny 1988
# This was written to movie_data.csv: Shanghai Surprise 1986
# This was written to movie_data.csv: Not of This Earth 1988
# This was written to movie_data.csv: Tapeheads 1988
# This was written to movie_data.csv: Ghoulies II 1987
# This was written to movie_data.csv: Love Streams 1984
# This was written to movie_data.csv: Appointment with Death 1988
# This was written to movie_data.csv: Born to Defense 1988
# This was written to movie_data.csv: 'night, Mother 1986
# This was written to movie_data.csv: Plenty 1985
# This was written to movie_data.csv: Claudine 1974
# This was written to movie_data.csv: Blood for Dracula 1974
# This was written to movie_data.csv: One on One 1977
# This was written to movie_data.csv: Cinderella 1977
# This was written to movie_data.csv: The Medusa Touch 1978
# This was written to movie_data.csv: Snuff 1975
# This was written to movie_data.csv: Dolemite 1975
# This was written to movie_data.csv: Kenny & Company 1976
# This was written to movie_data.csv: Good Guys Wear Black 1978
# This was written to movie_data.csv: The Last Remake of Beau Geste 1977
# This was written to movie_data.csv: Desperate Living 1977
# This was written to movie_data.csv: The Strongest Man in the World 1975
# This was written to movie_data.csv: Lifeguard 1976
# This was written to movie_data.csv: The Bermuda Triangle 1978
# This was written to movie_data.csv: The Day of the Dolphin 1973
# This was written to movie_data.csv: Blade 1973
# This was written to movie_data.csv: Detroit 9000 1973
# This was written to movie_data.csv: The Offence 1973
# This was written to movie_data.csv: The Valachi Papers 1972
# This was written to movie_data.csv: Tombs of the Blind Dead 1972
# This was written to movie_data.csv: The Lost Honor of Katharina Blum 1975
# This was written to movie_data.csv: The Island at the Top of the World 1974
# This was written to movie_data.csv: The Cars That Ate Paris 1974
# This was written to movie_data.csv: Celine and Julie Go Boating 1974
# This was written to movie_data.csv: The Trial of Billy Jack 1974
# This was written to movie_data.csv: Carry on Girls 1973
# This was written to movie_data.csv: Cleopatra Jones 1973
# This was written to movie_data.csv: The Last of Sheila 1973
# This was written to movie_data.csv: The Last American Hero 1973
# This was written to movie_data.csv: What Have You Done to Solange? 1972
# This was written to movie_data.csv: The Tall Blond Man with One Black Shoe 1972
# This was written to movie_data.csv: The Adventures of the Wilderness Family 1975
# This was written to movie_data.csv: The Other Side of the Mountain 1975
# This was written to movie_data.csv: Seven Beauties 1975
# This was written to movie_data.csv: Buffalo Bill and the Indians, or Sitting Bull's History Lesson 1976
# This was written to movie_data.csv: From Noon Till Three 1976
# This was written to movie_data.csv: Mr. Klein 1976
# This was written to movie_data.csv: Nickelodeon 1976
# This was written to movie_data.csv: No Deposit, No Return 1976
# This was written to movie_data.csv: The Shaggy D.A. 1976
# This was written to movie_data.csv: Semi-Tough 1977
# This was written to movie_data.csv: Which Way Is Up? 1977
# This was written to movie_data.csv: Kingdom of the Spiders 1977
# This was written to movie_data.csv: A Little Night Music 1977
# This was written to movie_data.csv: The Betsy 1978
# This was written to movie_data.csv: The Awakening 1980
# This was written to movie_data.csv: The Sensuous Nurse 1975
# This was written to movie_data.csv: The Cheap Detective 1978
# This was written to movie_data.csv: Get Out Your Handkerchiefs 1978
# This was written to movie_data.csv: Fedora 1978
# This was written to movie_data.csv: In Praise of Older Women 1978
# This was written to movie_data.csv: Cuba 1979
# This was written to movie_data.csv: Richard Pryor: Live in Concert 1979
# This was written to movie_data.csv: Ashanti 1979
# This was written to movie_data.csv: Hanky Panky 1982
# This was written to movie_data.csv: Kiss Me Goodbye 1982
# This was written to movie_data.csv: Beyond the Limit 1983
# This was written to movie_data.csv: Deal of the Century 1983
# This was written to movie_data.csv: Max Dugan Returns 1983
# This was written to movie_data.csv: Nate and Hayes 1983
# This was written to movie_data.csv: Nightmares 1983
# This was written to movie_data.csv: Yor: The Hunter from the Future 1983
# This was written to movie_data.csv: The Evil That Men Do 1984
# This was written to movie_data.csv: Finders Keepers 1984
# This was written to movie_data.csv: Flashpoint 1984
# This was written to movie_data.csv: The Little Drummer Girl 1984
# This was written to movie_data.csv: Making the Grade 1984
# This was written to movie_data.csv: Meatballs Part II 1984
# This was written to movie_data.csv: Oh, God! You Devil 1984
# This was written to movie_data.csv: The Bride 1985
# This was written to movie_data.csv: That's Dancing! 1985
# This was written to movie_data.csv: Turk 182 1985
# This was written to movie_data.csv: Care Bears Movie II: A New Generation 1986
# This was written to movie_data.csv: Playing for Keeps 1986
# This was written to movie_data.csv: Sweet Liberty 1986
# This was written to movie_data.csv: Tai-Pan 1986
# This was written to movie_data.csv: Assassination 1987
# This was written to movie_data.csv: From the Hip 1987
# This was written to movie_data.csv: Burglar 1987
# This was written to movie_data.csv: Everybody's All-American 1988
# This was written to movie_data.csv: Feds 1988
# This was written to movie_data.csv: Hot to Trot 1988
# This was written to movie_data.csv: The Rescue 1988
# This was written to movie_data.csv: Renegades 1989
# This was written to movie_data.csv: Shakedown 1988
# This was written to movie_data.csv: Dead Bang 1989
# This was written to movie_data.csv: Popcorn 1991
# This was written to movie_data.csv: Bingo 1991
# This was written to movie_data.csv: Mystery Date 1991
# This was written to movie_data.csv: Year of the Gun 1991
# This was written to movie_data.csv: Aces: Iron Eagle III 1992
# This was written to movie_data.csv: Folks! 1992
# This was written to movie_data.csv: The Public Eye 1992
# This was written to movie_data.csv: Whispers in the Dark 1992
# This was written to movie_data.csv: Year of the Comet 1992
# This was written to movie_data.csv: Hear No Evil 1993
# This was written to movie_data.csv: Lost in Yonkers 1993
# This was written to movie_data.csv: Father Hood 1993
# This was written to movie_data.csv: Car 54, Where Are You? 1994
# This was written to movie_data.csv: Clean Slate 1994
# This was written to movie_data.csv: A Good Man in Africa 1994
# This was written to movie_data.csv: The Jerky Boys 1995
# This was written to movie_data.csv: Top Dog 1995
# This was written to movie_data.csv: A Family Thing 1996
# This was written to movie_data.csv: Sunset Park 1996
# This was written to movie_data.csv: Dangerous Ground 1997
# This was written to movie_data.csv: That Old Feeling 1997
# This was written to movie_data.csv: Krippendorf's Tribe 1998
# This was written to movie_data.csv: Bats 1999
# This was written to movie_data.csv: Marci X 2003
# This was written to movie_data.csv: Teacher's Pet 2004
# This was written to movie_data.csv: Violent City 1970
# This was written to movie_data.csv: Beastmaster 2: Through the Portal of Time 1991
# This was written to movie_data.csv: Dragon Ball Z: The World's Strongest 1990
# This was written to movie_data.csv: The Adjuster 1991
# ...
# This was written to movie_data.csv: Gigi & Nate 2022
# This was written to movie_data.csv: E.T. the Extra-Terrestrial 2022
# This was written to movie_data.csv: The Good House 2022
# This was written to movie_data.csv: Decision to Leave 2022
# This was written to movie_data.csv: Emily the Criminal 2022
# This was written to movie_data.csv: Umma 2022
# This was written to movie_data.csv: The Wolf and the Lion 2022
# This was written to movie_data.csv: Jeepers Creepers: Reborn 2022
# This was written to movie_data.csv: Watcher 2022
# This was written to movie_data.csv: Mr. Malcolm's List 2022
# This was written to movie_data.csv: Armageddon Time 2022
# This was written to movie_data.csv: Radhe Shyam 2022
# This was written to movie_data.csv: Vikram 2022
# This was written to movie_data.csv: Aftersun 2022
# This was written to movie_data.csv: Infinite Storm 2022
# This was written to movie_data.csv: Vikram Vedha 2022
# This was written to movie_data.csv: The Duke 2022
# This was written to movie_data.csv: Running the Bases 2022
# This was written to movie_data.csv: ¿Y cómo es él? 2022
# This was written to movie_data.csv: The Kashmir Files 2022
# This was written to movie_data.csv: 2000 Mules 2022
# This was written to movie_data.csv: It's a Wonderful Life 2022
# This was written to movie_data.csv: The Godfather 2022
# This was written to movie_data.csv: Spoiler Alert 2022
# This was written to movie_data.csv: Medieval 2022
# This was written to movie_data.csv: Rogue One: A Star Wars Story 2022
# This was written to movie_data.csv: Howl's Moving Castle 2022
# This was written to movie_data.csv: Empire of Light 2022
# This was written to movie_data.csv: F3: Fun and Frustration 2022
# This was written to movie_data.csv: Fire of Love 2022
# This was written to movie_data.csv: After Ever Happy 2022
# This was written to movie_data.csv: EO 2022
# This was written to movie_data.csv: Hallelujah: Leonard Cohen, a Journey, a Song 2022
# This was written to movie_data.csv: Broker 2022
# This was written to movie_data.csv: The Contractor 2022
# This was written to movie_data.csv: Jug Jugg Jeeyo 2022
# This was written to movie_data.csv: The Beatles: Get Back - The Rooftop Concert 2022
# This was written to movie_data.csv: Man of God 2022
# This was written to movie_data.csv: Hansan: Rising Dragon 2022
# This was written to movie_data.csv: Johnny Cash: The Redemption of an American Icon 2022
# This was written to movie_data.csv: The Tiger Rising 2022
# This was written to movie_data.csv: Coraline 2022
# This was written to movie_data.csv: Acharya 2022
# This was written to movie_data.csv: Petite Maman 2022
# This was written to movie_data.csv: The Roundup 2022
# This was written to movie_data.csv: Evangelion: 3.0+1.01 Thrice Upon a Time 2022
# This was written to movie_data.csv: Star Trek II: The Wrath of Khan 2022
# This was written to movie_data.csv: The Phantom of the Open 2022
# This was written to movie_data.csv: Corsage 2022
# This was written to movie_data.csv: Saint Michael Meet the Angel 2022
# This was written to movie_data.csv: Unsilenced 2022
# This was written to movie_data.csv: Ante Sundharaniki 2022
# This was written to movie_data.csv: Back to the Drive-in 2022
# This was written to movie_data.csv: The Mean One 2022
# This was written to movie_data.csv: Official Competition 2022
# This was written to movie_data.csv: HIT: The 2nd Case 2022
# This was written to movie_data.csv: Gangubai Kathiawadi 2022
# This was written to movie_data.csv: Cuando sea joven 2022
# This was written to movie_data.csv: Confess, Fletch 2022
# This was written to movie_data.csv: Call Jane 2022
# This was written to movie_data.csv: The Quintessential Quintuplets Movie 2022
# This was written to movie_data.csv: God's Country 2022
# This was written to movie_data.csv: All the Beauty and the Bloodshed 2022
# This was written to movie_data.csv: The Railway Children Return 2022
# This was written to movie_data.csv: Deep in the Heart: A Texas Wildlife Story 2022
# This was written to movie_data.csv: Vivo 2022
# This was written to movie_data.csv: Eiffel 2022
# This was written to movie_data.csv: Brian and Charles 2022
# This was written to movie_data.csv: Selena 2022
# This was written to movie_data.csv: Emergency Declaration 2022
# This was written to movie_data.csv: Facing Nolan 2022
# This was written to movie_data.csv: Tyson's Run 2022
# This was written to movie_data.csv: Superspreader 2022
# This was written to movie_data.csv: The Inspection 2022
# This was written to movie_data.csv: Alice 2022
# This was written to movie_data.csv: The Good Boss 2022
# This was written to movie_data.csv: Hawa 2022
# This was written to movie_data.csv: Inu-oh 2022
# This was written to movie_data.csv: The Forgiven 2022
# This was written to movie_data.csv: Fourth of July 2022
# This was written to movie_data.csv: Barbie 2023
# This was written to movie_data.csv: The Super Mario Bros. Movie 2023
# This was written to movie_data.csv: Spider-Man: Across the Spider-Verse 2023
# This was written to movie_data.csv: Guardians of the Galaxy Vol. 3 2023
# This was written to movie_data.csv: Oppenheimer 2023
# This was written to movie_data.csv: The Little Mermaid 2023
# This was written to movie_data.csv: Wonka 2023
# This was written to movie_data.csv: Ant-Man and the Wasp: Quantumania 2023
# This was written to movie_data.csv: John Wick: Chapter 4 2023
# This was written to movie_data.csv: Sound of Freedom 2023
# This was written to movie_data.csv: Indiana Jones and the Dial of Destiny 2023
# This was written to movie_data.csv: Taylor Swift: The Eras Tour 2023
# This was written to movie_data.csv: Mission: Impossible - Dead Reckoning Part One 2023
# This was written to movie_data.csv: The Hunger Games: The Ballad of Songbirds & Snakes 2023
# This was written to movie_data.csv: Transformers: Rise of the Beasts 2023
# This was written to movie_data.csv: Creed III 2023
# This was written to movie_data.csv: Elemental 2023
# This was written to movie_data.csv: Fast X 2023
# This was written to movie_data.csv: Five Nights at Freddy's 2023
# This was written to movie_data.csv: Migration 2023
# This was written to movie_data.csv: Aquaman and the Lost Kingdom 2023
# This was written to movie_data.csv: Teenage Mutant Ninja Turtles: Mutant Mayhem 2023
# This was written to movie_data.csv: Scream VI 2023
# This was written to movie_data.csv: Trolls Band Together 2023
# This was written to movie_data.csv: M3GAN 2023
# This was written to movie_data.csv: Dungeons & Dragons: Honor Among Thieves 2023
# This was written to movie_data.csv: The Equalizer 3 2023
# This was written to movie_data.csv: Anyone But You 2023
# This was written to movie_data.csv: The Nun II 2023
# This was written to movie_data.csv: The Marvels 2023
# This was written to movie_data.csv: Meg 2: The Trench 2023
# This was written to movie_data.csv: Insidious: The Red Door 2023
# This was written to movie_data.csv: Blue Beetle 2023
# This was written to movie_data.csv: Evil Dead Rise 2023
# This was written to movie_data.csv: The Exorcist: Believer 2023
# This was written to movie_data.csv: PAW Patrol: The Mighty Movie 2023
# This was written to movie_data.csv: Cocaine Bear 2023
# This was written to movie_data.csv: Wish 2023
# This was written to movie_data.csv: The Color Purple 2023
# This was written to movie_data.csv: Shazam! Fury of the Gods 2023
# This was written to movie_data.csv: Saw X 2023
# This was written to movie_data.csv: Godzilla Minus One 2023
# This was written to movie_data.csv: Jesus Revolution 2023
# This was written to movie_data.csv: Air 2023
# This was written to movie_data.csv: No Hard Feelings 2023
# This was written to movie_data.csv: Talk to Me 2023
# This was written to movie_data.csv: The Boy and the Heron 2023
# This was written to movie_data.csv: Gran Turismo 2023
# This was written to movie_data.csv: The Boogeyman 2023
# This was written to movie_data.csv: A Haunting in Venice 2023
# This was written to movie_data.csv: The Creator 2023
# This was written to movie_data.csv: 80 for Brady 2023
# This was written to movie_data.csv: Knock at the Cabin 2023
# This was written to movie_data.csv: The Iron Claw 2023
# This was written to movie_data.csv: Poor Things 2023
# This was written to movie_data.csv: Missing 2023
# This was written to movie_data.csv: Renaissance: A Film by Beyoncé 2023
# This was written to movie_data.csv: Plane 2023
# This was written to movie_data.csv: 65 2023
# This was written to movie_data.csv: Thanksgiving 2023
# This was written to movie_data.csv: My Big Fat Greek Wedding 3 2023
# This was written to movie_data.csv: Asteroid City 2023
# This was written to movie_data.csv: Magic Mike's Last Dance 2023
# This was written to movie_data.csv: Strays 2023
# This was written to movie_data.csv: American Fiction 2023
# This was written to movie_data.csv: Priscilla 2023
# This was written to movie_data.csv: Are You There God? It's Me, Margaret. 2023
# This was written to movie_data.csv: The Holdovers 2023
# This was written to movie_data.csv: The Pope's Exorcist 2023
# This was written to movie_data.csv: Ferrari 2023
# This was written to movie_data.csv: The Blackening 2023
# This was written to movie_data.csv: Book Club: The Next Chapter 2023
# This was written to movie_data.csv: Pathaan 2023
# This was written to movie_data.csv: Renfield 2023
# This was written to movie_data.csv: The Blind 2023
# This was written to movie_data.csv: Guy Ritchie's the Covenant 2023
# This was written to movie_data.csv: The Expendables 4 2023
# This was written to movie_data.csv: Champions 2023
# This was written to movie_data.csv: Ruby Gillman: Teenage Kraken 2023
# This was written to movie_data.csv: Jawan 2023
# This was written to movie_data.csv: Titanic 2023
# This was written to movie_data.csv: Dumb Money 2023
# This was written to movie_data.csv: Animal 2023
# This was written to movie_data.csv: The Last Voyage of the Demeter 2023
# This was written to movie_data.csv: Joy Ride 2023
# This was written to movie_data.csv: His Only Son 2023
# This was written to movie_data.csv: The Shift 2023
# This was written to movie_data.csv: About My Father 2023
# This was written to movie_data.csv: Bottoms 2023
# This was written to movie_data.csv: After Death 2023
# This was written to movie_data.csv: Saltburn 2023
# This was written to movie_data.csv: Past Lives 2023
# This was written to movie_data.csv: Suzume 2023
# This was written to movie_data.csv: The Machine 2023
# This was written to movie_data.csv: The Nightmare Before Christmas 2023
# This was written to movie_data.csv: Demon Slayer: Kimetsu No Yaiba - To the Swordsmith Village 2023
# This was written to movie_data.csv: House Party 2023
# This was written to movie_data.csv: Radical 2023
# This was written to movie_data.csv: Salaar 2023
# This was written to movie_data.csv: The Zone of Interest 2023
# This was written to movie_data.csv: Beau Is Afraid 2023
# This was written to movie_data.csv: BTS: Yet to Come in Cinemas 2023
# This was written to movie_data.csv: Silent Night 2023
# This was written to movie_data.csv: The Hill 2023
# This was written to movie_data.csv: Dunki 2023
# This was written to movie_data.csv: Sisu 2023
# This was written to movie_data.csv: Retribution 2023
# This was written to movie_data.csv: Coraline 2023
# This was written to movie_data.csv: Star Wars: Episode VI - Return of the Jedi 2023
# This was written to movie_data.csv: Journey to Bethlehem 2023
# This was written to movie_data.csv: Next Goal Wins 2023
# This was written to movie_data.csv: Operation Fortune: Ruse de Guerre 2023
# This was written to movie_data.csv: Love Again 2023
# This was written to movie_data.csv: Dream Scenario 2023
# This was written to movie_data.csv: The Chosen Season 3 Finale 2023
# This was written to movie_data.csv: Big George Foreman 2023
# This was written to movie_data.csv: Nefarious 2023
# This was written to movie_data.csv: Waitress: The Musical 2023
# This was written to movie_data.csv: Tiger 3 2023
# This was written to movie_data.csv: Freelance 2023
# This was written to movie_data.csv: Infinity Pool 2023
# This was written to movie_data.csv: Stop Making Sense 2023
# This was written to movie_data.csv: The Wandering Earth II 2023
# This was written to movie_data.csv: Anatomy of a Fall 2023
# This was written to movie_data.csv: Hocus Pocus 2023
# This was written to movie_data.csv: You Hurt My Feelings 2023
# This was written to movie_data.csv: Kandahar 2023
# This was written to movie_data.csv: Golda 2023
# This was written to movie_data.csv: It Lives Inside 2023
# This was written to movie_data.csv: Origin 2023
# This was written to movie_data.csv: Hypnotic 2023
# This was written to movie_data.csv: Marlowe 2023
# This was written to movie_data.csv: The Amazing Maurice 2023
# This was written to movie_data.csv: Mummies 2023
# This was written to movie_data.csv: Theater Camp 2023
# This was written to movie_data.csv: Left Behind: Rise of the Antichrist 2023
# This was written to movie_data.csv: Ponniyin Selvan: Part Two 2023
# This was written to movie_data.csv: The Journey: A Music Special from Andrea Bocelli 2023
# This was written to movie_data.csv: Chevalier 2023
# This was written to movie_data.csv: Mafia Mamma 2023
# This was written to movie_data.csv: A Thousand and One 2023
# This was written to movie_data.csv: What Happens Later 2023
# This was written to movie_data.csv: 2023 Oscar Nominated Short Films: Live Action 2023
# This was written to movie_data.csv: Jurassic Park 2023
# This was written to movie_data.csv: Tu Jhoothi Main Makkaar 2023
# This was written to movie_data.csv: Problemista 2023
# This was written to movie_data.csv: Come Out in Jesus Name 2023
# This was written to movie_data.csv: The Miracle Club 2023
# This was written to movie_data.csv: A Good Person 2023
# This was written to movie_data.csv: Moving On 2023
# This was written to movie_data.csv: Fear 2023
# This was written to movie_data.csv: Winnie-the-Pooh: Blood and Honey 2023
# This was written to movie_data.csv: Skinamarink 2023
# This was written to movie_data.csv: Die Hard 2023
# This was written to movie_data.csv: Jules 2023
# This was written to movie_data.csv: Somewhere in Queens 2023
# This was written to movie_data.csv: The Marsh King's Daughter 2023
# This was written to movie_data.csv: Lost in the Stars 2023
# This was written to movie_data.csv: Oldboy 2023
# This was written to movie_data.csv: Creation of the Gods I: Kingdom of Storms 2023
# This was written to movie_data.csv: Route 60: The Biblical Highway 2023
# This was written to movie_data.csv: The Retirement Plan 2023
# This was written to movie_data.csv: Polite Society 2023
# This was written to movie_data.csv: The Quiet Girl 2023
# This was written to movie_data.csv: BlackBerry 2023
# This was written to movie_data.csv: Spirited Away 2023
# This was written to movie_data.csv: Dicks: The Musical 2023
# This was written to movie_data.csv: Maybe I Do 2023
# This was written to movie_data.csv: Eileen 2023
# This was written to movie_data.csv: The First Slam Dunk 2023
# This was written to movie_data.csv: Billie Eilish Live at the O2 2023
# This was written to movie_data.csv: The Lost King 2023
# This was written to movie_data.csv: The Lord of the Rings: The Return of the King 2023
# This was written to movie_data.csv: Camp Hideout 2023
# This was written to movie_data.csv: Close 2023
# This was written to movie_data.csv: Emily 2023
# This was written to movie_data.csv: Fallen Leaves 2023
# This was written to movie_data.csv: Knights of the Zodiac 2023
# This was written to movie_data.csv: Inside 2023
# This was written to movie_data.csv: The Roundup: No Way Out 2023
# This was written to movie_data.csv: Freud's Last Session 2023
# This was written to movie_data.csv: Fool's Paradise 2023
# This was written to movie_data.csv: The Domino Revival 2023
# This was written to movie_data.csv: Paint 2023
# This was written to movie_data.csv: It's a Wonderful Knife 2023
# This was written to movie_data.csv: Hidden Blade 2023
# This was written to movie_data.csv: Return to Seoul 2023
# This was written to movie_data.csv: The Royal Hotel 2023
# This was written to movie_data.csv: Roll with It 2023
# This was written to movie_data.csv: The Devil Conspiracy 2023
# This was written to movie_data.csv: Showing Up 2023
# This was written to movie_data.csv: Rally Road Racers 2023
# This was written to movie_data.csv: How to Blow Up a Pipeline 2023

# %% [markdown]
# # IGNORE BELOW!

# %%
#Error occurred with request to OMDB regarding ('Hannah and Her Sisters', '1986').

# %%
# Check status of data pull:
df2 = pd.read_csv('movie_data.csv')
df2.shape

df2[df2.duplicated() == True]
# Out:
# Empty DataFrame
# Columns: [Title, Year, Genre(s), IMDB, Rotten Tomatoes, Metacritic, TMDB, # of IMDB Votes, # of Awards, Gross Domestic Box Office Sales ($), Media, Directors, Origin]
# Index: []

# %%
df2.shape
# Out:
# (12397, 13)

# %%
df2_no_dups = df2.drop_duplicates()
df2_no_dups[df2_no_dups.duplicated() == True]
# Out:
# Empty DataFrame
# Columns: [Title, Year, Genre(s), IMDB, Rotten Tomatoes, Metacritic, TMDB, # of IMDB Votes, # of Awards, Gross Domestic Box Office Sales ($), Media, Directors, Origin]
# Index: []

# %%
df2_no_dups.shape
# Out:
# (10766, 13)

# %%
df2_no_dups.to_excel('df2_no_dups.xlsx')

# %%
df3 = pd.read_csv('no_dups_movie_year_from_1972_2023.csv')
df3.shape
# Out:
# (12397, 2)

# %%
if start != 1:
    while (row[0] + '/' + row[1] != start):
        unwanted_row = next(reader)
    for row in reader:
        new_movie = Movie(row[0],row[1])
        new_movie.get_movie_data()
